# %% [markdown]
# # Data Cleaning - QCEW
# Data cleaning for ECON672 Project

# %%
# %%capture
# Capture suppresses output to screen
import stata_setup
stata_setup.config("/Applications/Stata 17", "be")

# %%
# %%stata
# /* Define paths for data and output */
# global data "Data"
# global output "Output"
# global raw "$data/Raw"
# global rawEmploy "$raw/QCEW/Employment"
# global rawPay "$raw/QCEW/AnnualPay"
# global processed "$data/Processed"
# global processedEmploy "$processed/QCEW/Employment"
# global processedPay "$processed/QCEW/AnnualPay"
#
#
# global finalEmploy "$processed/QCEW/MergedEmploy.dta"
# global finalQCEWData "$processed/QCEW/MergedQCEW.dta"
# Out:
# . /* Define paths for data and output */
# . global data "Data"
#
# . global output "Output"
#
# . global raw "$data/Raw"
#
# . global rawEmploy "$raw/QCEW/Employment"
#
# . global rawPay "$raw/QCEW/AnnualPay"
#
# . global processed "$data/Processed"
#
# . global processedEmploy "$processed/QCEW/Employment"
#
# . global processedPay "$processed/QCEW/AnnualPay"
#
# .
# .
# . global finalEmploy "$processed/QCEW/MergedEmploy.dta"
#
# . global finalQCEWData "$processed/QCEW/MergedQCEW.dta"
#
# .

# %%
# %%capture
# %%stata
log using "$output/dataClean-syth.log", replace

# %% [markdown]
# ## Import Wage and Workforce data
# Data is for NAICS 3364, Aircraft manufacturing from BLS QCEW
#
# | i.year | c.employ | c.wage | i.state |
# | --- | ---- | --- | --- |
# | year | employment | wage |  MO |
# | year | employment | wage |  WA |

# %% [markdown]
# ## Import  Employment Numbers from the States

# %%
# %%stata
# /* Read all the xlsx files into Stata files */
# local fileList: dir "$rawEmploy" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#     di ">>>Importing data for ", thisState, ": `thisFile'"
#     import excel "$rawEmploy/`thisFile'", ///
#     sheet("BLS Data Series") ///
#     cellrange(A14:N34) ///
#     firstrow ///
#     clear
#
#     /* This will be defaulted to int sometimes
#         and long others.  Force all files to be
#         long dataype
#     */
#     recast long Annual
#
#     /* Drop unneeded data and fix variable names
#         Note: Employment data is reported annually
#     */
#     keep Year Annual
#     rename Year year
#     rename Annual employment
#     label variable ///
#         employment "Annual Reported Employment (NAICS 3364)"
#
#     local dtaFile: di (thisState+".dta")
#     save "$processedEmploy/`dtaFile'", replace
# }
# Out:
# . /* Read all the xlsx files into Stata files */
# . local fileList: dir "$rawEmploy" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
# >
#   4.
# .     di ">>>Importing data for ", thisState, ": `thisFile'"
#   5.     import excel "$rawEmploy/`thisFile'", ///
# >     sheet("BLS Data Series") ///
# >     cellrange(A14:N34) ///
# >     firstrow ///
# >     clear
#   6.
# .     /* This will be defaulted to int sometimes
# >         and long others.  Force all files to be
# >         long dataype
# >     */
# .     recast long Annual
#   7.
# .     /* Drop unneeded data and fix variable names
# >         Note: Employment data is reported annually
# >     */
# .     keep Year Annual
#   8.     rename Year year
#   9.     rename Annual employment
#  10.     label variable ///
# >         employment "Annual Reported Employment (NAICS 3364)"
#  11.
# .     local dtaFile: di (thisState+".dta")
#  12.     save "$processedEmploy/`dtaFile'", replace
#  13. }
# >>>Importing data for  OH : OH.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/OH.dta saved
# >>>Importing data for  FL : FL.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/FL.dta saved
# >>>Importing data for  AR : AR.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/AR.dta saved
# >>>Importing data for  MD : MD.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/MD.dta saved
# >>>Importing data for  SC : SC.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/SC.dta saved
# >>>Importing data for  WV : WV.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/WV.dta saved
# >>>Importing data for  MI : MI.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/MI.dta saved
# >>>Importing data for  NC : NC.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/NC.dta saved
# >>>Importing data for  NH : NH.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/NH.dta saved
# >>>Importing data for  TN : TN.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/TN.dta saved
# >>>Importing data for  CT : CT.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/CT.dta saved
# >>>Importing data for  CA : CA.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/CA.dta saved
# >>>Importing data for  GA : GA.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/GA.dta saved
# >>>Importing data for  IN : IN.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/IN.dta saved
# >>>Importing data for  WI : WI.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/WI.dta saved
# >>>Importing data for  MO : MO.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/MO.dta saved
# >>>Importing data for  AL : AL.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/AL.dta saved
# >>>Importing data for  CO : CO.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/CO.dta saved
# >>>Importing data for  NJ : NJ.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/NJ.dta saved
# >>>Importing data for  AZ : AZ.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/AZ.dta saved
# >>>Importing data for  PA : PA.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/PA.dta saved
# >>>Importing data for  IL : IL.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/IL.dta saved
# >>>Importing data for  VA : VA.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/VA.dta saved
# >>>Importing data for  TX : TX.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/TX.dta saved
# >>>Importing data for  MA : MA.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/MA.dta saved
# >>>Importing data for  KY : KY.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/KY.dta saved
# >>>Importing data for  NY : NY.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/NY.dta saved
# >>>Importing data for  MS : MS.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/MS.dta saved
# >>>Importing data for  NM : NM.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/NM.dta saved
# >>>Importing data for  OK : OK.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/OK.dta saved
# >>>Importing data for  WA : WA.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/WA.dta saved
# >>>Importing data for  OR : OR.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/OR.dta saved
# >>>Importing data for  UT : UT.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/UT.dta saved
# >>>Importing data for  KS : KS.xlsx
# (14 vars, 20 obs)
# file Data/Processed/QCEW/Employment/KS.dta saved
#
# .

# %%
# %%stata
# /* Append all the State-level Stata files into a single file */
# local fileList: dir "$processedEmploy" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#
#     /* Special actions for first file */
#     if `i'==1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         use "$processedEmploy/`thisFile'", clear
#         generate state = thisState
#     }
#
#     /* Actions for all subsequent files */
#     if `i'!=1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         append using "$processedEmploy/`thisFile'"
#         replace state = thisState if state==""
#     }
#
#     if `i'==`n_files'{
#         save "$finalEmploy", replace
#     }
#
# }
# Out:
# . /* Append all the State-level Stata files into a single file */
# . local fileList: dir "$processedEmploy" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
# >
#   4.
# .
# .     /* Special actions for first file */
# .     if `i'==1 {
#   5.         di ">>>Importing data for ", thisState, ": `thisFile'"
#   6.         use "$processedEmploy/`thisFile'", clear
#   7.         generate state = thisState
#   8.     }
#   9.
# .     /* Actions for all subsequent files */
# .     if `i'!=1 {
#  10.         di ">>>Importing data for ", thisState, ": `thisFile'"
#  11.         append using "$processedEmploy/`thisFile'"
#  12.         replace state = thisState if state==""
#  13.     }
#  14.
# .     if `i'==`n_files'{
#  15.         save "$finalEmploy", replace
#  16.     }
#  17.
# . }
# >>>Importing data for  GA : GA.dta
# >>>Importing data for  KS : KS.dta
# (20 real changes made)
# >>>Importing data for  IL : IL.dta
# (20 real changes made)
# >>>Importing data for  SC : SC.dta
# (20 real changes made)
# >>>Importing data for  IN : IN.dta
# (20 real changes made)
# >>>Importing data for  NM : NM.dta
# (20 real changes made)
# >>>Importing data for  MA : MA.dta
# (20 real changes made)
# >>>Importing data for  OH : OH.dta
# (20 real changes made)
# >>>Importing data for  NY : NY.dta
# (20 real changes made)
# >>>Importing data for  OK : OK.dta
# (20 real changes made)
# >>>Importing data for  WI : WI.dta
# (20 real changes made)
# >>>Importing data for  AR : AR.dta
# (20 real changes made)
# >>>Importing data for  NJ : NJ.dta
# (20 real changes made)
# >>>Importing data for  MD : MD.dta
# (20 real changes made)
# >>>Importing data for  NH : NH.dta
# (20 real changes made)
# >>>Importing data for  MS : MS.dta
# (20 real changes made)
# >>>Importing data for  CO : CO.dta
# (20 real changes made)
# >>>Importing data for  UT : UT.dta
# (20 real changes made)
# >>>Importing data for  CT : CT.dta
# (20 real changes made)
# >>>Importing data for  MI : MI.dta
# (20 real changes made)
# >>>Importing data for  VA : VA.dta
# (20 real changes made)
# >>>Importing data for  CA : CA.dta
# (20 real changes made)
# >>>Importing data for  AZ : AZ.dta
# (20 real changes made)
# >>>Importing data for  WV : WV.dta
# (20 real changes made)
# >>>Importing data for  WA : WA.dta
# (20 real changes made)
# >>>Importing data for  AL : AL.dta
# (20 real changes made)
# >>>Importing data for  MO : MO.dta
# (20 real changes made)
# >>>Importing data for  NC : NC.dta
# (20 real changes made)
# >>>Importing data for  OR : OR.dta
# (20 real changes made)
# >>>Importing data for  TX : TX.dta
# (20 real changes made)
# >>>Importing data for  TN : TN.dta
# (20 real changes made)
# >>>Importing data for  FL : FL.dta
# (20 real changes made)
# >>>Importing data for  PA : PA.dta
# (20 real changes made)
# >>>Importing data for  KY : KY.dta
# (20 real changes made)
# file Data/Processed/QCEW/MergedEmploy.dta saved
#
# .

# %%
# %%stata
# describe
# Out:
# Contains data from Data/Processed/QCEW/MergedEmploy.dta
#  Observations:           680
#     Variables:             3                  5 Feb 2022 16:28
# -------------------------------------------------------------------------------
# Variable      Storage   Display    Value
#     name         type    format    label      Variable label
# -------------------------------------------------------------------------------
# year            int     %10.0g                Year
# employment      long    %10.0g                Annual Reported Employment (NAICS
#                                                 3364)
# state           str2    %9s
# -------------------------------------------------------------------------------
# Sorted by:

# %% [markdown]
# ---

# %% [markdown]
# ## Import annual pay data from the states.

# %% [markdown]
# Create "working" frame and change to "working".
# The "default" frame with be merged with the "working" frame to
# create the primary dataset for analysis.

# %%
# %%stata
# frame create working
# frame change working
# Out:
# . frame create working
#
# . frame change working
#
# .

# %%
# %%stata
# /* Read all the xlsx files into Stata files */
# local fileList: dir "$rawPay" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#     di ">>>Importing data for ", thisState, ": `thisFile'"
#     import excel "$rawPay/`thisFile'", ///
#     sheet("BLS Data Series") ///
#     cellrange(A14:B34) ///
#     firstrow ///
#     clear
#
#     /* This will be defaulted to int sometimes
#         and long others.  Force all files to be
#         long dataype
#     */
#     recast long Annual
#
#     /* Fix variable names */
#     rename Year year
#     rename Annual annualPay
#     label variable annual "Average Annual Pay (USD) (NAICS 3364)"
#
#     local dtaFile: di (thisState+".dta")
#     save "$processedPay/`dtaFile'", replace
# }
# Out:
# . /* Read all the xlsx files into Stata files */
# . local fileList: dir "$rawPay" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
# >
#   4.
# .     di ">>>Importing data for ", thisState, ": `thisFile'"
#   5.     import excel "$rawPay/`thisFile'", ///
# >     sheet("BLS Data Series") ///
# >     cellrange(A14:B34) ///
# >     firstrow ///
# >     clear
#   6.
# .     /* This will be defaulted to int sometimes
# >         and long others.  Force all files to be
# >         long dataype
# >     */
# .     recast long Annual
#   7.
# .     /* Fix variable names */
# .     rename Year year
#   8.     rename Annual annualPay
#   9.     label variable annual "Average Annual Pay (USD) (NAICS 3364)"
#  10.
# .     local dtaFile: di (thisState+".dta")
#  11.     save "$processedPay/`dtaFile'", replace
#  12. }
# >>>Importing data for  OH : OH.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/OH.dta saved
# >>>Importing data for  FL : FL.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/FL.dta saved
# >>>Importing data for  AR : AR.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/AR.dta saved
# >>>Importing data for  MD : MD.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/MD.dta saved
# >>>Importing data for  SC : SC.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/SC.dta saved
# >>>Importing data for  WV : WV.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/WV.dta saved
# >>>Importing data for  MI : MI.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/MI.dta saved
# >>>Importing data for  NC : NC.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/NC.dta saved
# >>>Importing data for  NH : NH.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/NH.dta saved
# >>>Importing data for  TN : TN.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/TN.dta saved
# >>>Importing data for  CT : CT.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/CT.dta saved
# >>>Importing data for  CA : CA.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/CA.dta saved
# >>>Importing data for  GA : GA.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/GA.dta saved
# >>>Importing data for  IN : IN.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/IN.dta saved
# >>>Importing data for  WI : WI.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/WI.dta saved
# >>>Importing data for  MO : MO.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/MO.dta saved
# >>>Importing data for  AL : AL.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/AL.dta saved
# >>>Importing data for  CO : CO.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/CO.dta saved
# >>>Importing data for  NJ : NJ.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/NJ.dta saved
# >>>Importing data for  AZ : AZ.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/AZ.dta saved
# >>>Importing data for  PA : PA.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/PA.dta saved
# >>>Importing data for  IL : IL.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/IL.dta saved
# >>>Importing data for  VA : VA.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/VA.dta saved
# >>>Importing data for  TX : TX.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/TX.dta saved
# >>>Importing data for  MA : MA.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/MA.dta saved
# >>>Importing data for  KY : KY.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/KY.dta saved
# >>>Importing data for  NY : NY.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/NY.dta saved
# >>>Importing data for  MS : MS.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/MS.dta saved
# >>>Importing data for  NM : NM.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/NM.dta saved
# >>>Importing data for  OK : OK.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/OK.dta saved
# >>>Importing data for  WA : WA.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/WA.dta saved
# >>>Importing data for  OR : OR.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/OR.dta saved
# >>>Importing data for  UT : UT.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/UT.dta saved
# >>>Importing data for  KS : KS.xlsx
# (2 vars, 20 obs)
# file Data/Processed/QCEW/AnnualPay/KS.dta saved
#
# .

# %%
# %%stata
# /* Append all the State-level Stata files into a single file */
# local fileList: dir "$processedPay" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#
#     /* Special actions for first file */
#     if `i'==1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         use "$processedPay/`thisFile'", clear
#         generate state = thisState
#     }
#
#     /* Actions for all subsequent files */
#     if `i'!=1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         append using "$processedPay/`thisFile'"
#         replace state = thisState if state==""
#     }
#
#     if `i'==`n_files'{
#         save "$MergedPay", replace
#     }
#
# }
# Out:
# . /* Append all the State-level Stata files into a single file */
# . local fileList: dir "$processedPay" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
# >
#   4.
# .
# .     /* Special actions for first file */
# .     if `i'==1 {
#   5.         di ">>>Importing data for ", thisState, ": `thisFile'"
#   6.         use "$processedPay/`thisFile'", clear
#   7.         generate state = thisState
#   8.     }
#   9.
# .     /* Actions for all subsequent files */
# .     if `i'!=1 {
#  10.         di ">>>Importing data for ", thisState, ": `thisFile'"
#  11.         append using "$processedPay/`thisFile'"
#  12.         replace state = thisState if state==""
#  13.     }
#  14.
# .     if `i'==`n_files'{
#  15.         save "$MergedPay", replace
#  16.     }
#  17.
# . }
# >>>Importing data for  GA : GA.dta
# >>>Importing data for  KS : KS.dta
# (20 real changes made)
# >>>Importing data for  IL : IL.dta
# (20 real changes made)
# >>>Importing data for  SC : SC.dta
# (20 real changes made)
# >>>Importing data for  IN : IN.dta
# (20 real changes made)
# >>>Importing data for  NM : NM.dta
# (20 real changes made)
# >>>Importing data for  MA : MA.dta
# (20 real changes made)
# >>>Importing data for  OH : OH.dta
# (20 real changes made)
# >>>Importing data for  NY : NY.dta
# (20 real changes made)
# >>>Importing data for  OK : OK.dta
# (20 real changes made)
# >>>Importing data for  WI : WI.dta
# (20 real changes made)
# >>>Importing data for  AR : AR.dta
# (20 real changes made)
# >>>Importing data for  NJ : NJ.dta
# (20 real changes made)
# >>>Importing data for  MD : MD.dta
# (20 real changes made)
# >>>Importing data for  NH : NH.dta
# (20 real changes made)
# >>>Importing data for  MS : MS.dta
# (20 real changes made)
# >>>Importing data for  CO : CO.dta
# (20 real changes made)
# >>>Importing data for  UT : UT.dta
# (20 real changes made)
# >>>Importing data for  CT : CT.dta
# (20 real changes made)
# >>>Importing data for  MI : MI.dta
# (20 real changes made)
# >>>Importing data for  VA : VA.dta
# (20 real changes made)
# >>>Importing data for  CA : CA.dta
# (20 real changes made)
# >>>Importing data for  AZ : AZ.dta
# (20 real changes made)
# >>>Importing data for  WV : WV.dta
# (20 real changes made)
# >>>Importing data for  WA : WA.dta
# (20 real changes made)
# >>>Importing data for  AL : AL.dta
# (20 real changes made)
# >>>Importing data for  MO : MO.dta
# (20 real changes made)
# >>>Importing data for  NC : NC.dta
# Exception in thread Stata:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Applications/Stata 17/utilities/pystata/core/stout.py", line 176, in run
#     raise SystemError(output)
# SystemError: (20 real changes made)
# >>>Importing data for  OR : OR.dta
# (20 real changes made)
# >>>Importing data for  TX : TX.dta
# (20 real changes made)
# >>>Importing data for  TN : TN.dta
# (20 real changes made)
# >>>Importing data for  FL : FL.dta
# (20 real changes made)
# >>>Importing data for  PA : PA.dta
# (20 real changes made)
# >>>Importing data for  KY : KY.dta
# (20 real changes made)
# invalid file specification
# r(198);
# r(198);

# %%
# %%stata
# describe
# tab state
# Out:
# . describe
#
# Contains data from Data/Processed/QCEW/AnnualPay/GA.dta
#  Observations:           680
#     Variables:             3                  5 Feb 2022 16:28
# -------------------------------------------------------------------------------
# Variable      Storage   Display    Value
#     name         type    format    label      Variable label
# -------------------------------------------------------------------------------
# year            int     %10.0g                Year
# annualPay       long    %10.0g                Average Annual Pay (USD) (NAICS
#                                                 3364)
# state           str2    %9s
# -------------------------------------------------------------------------------
# Sorted by:
#      Note: Dataset has changed since last saved.
#
# . tab state
#
#       state |      Freq.     Percent        Cum.
# ------------+-----------------------------------
#          AL |         20        2.94        2.94
#          AR |         20        2.94        5.88
#          AZ |         20        2.94        8.82
#          CA |         20        2.94       11.76
#          CO |         20        2.94       14.71
#          CT |         20        2.94       17.65
#          FL |         20        2.94       20.59
#          GA |         20        2.94       23.53
#          IL |         20        2.94       26.47
#          IN |         20        2.94       29.41
#          KS |         20        2.94       32.35
#          KY |         20        2.94       35.29
#          MA |         20        2.94       38.24
#          MD |         20        2.94       41.18
#          MI |         20        2.94       44.12
#          MO |         20        2.94       47.06
#          MS |         20        2.94       50.00
#          NC |         20        2.94       52.94
#          NH |         20        2.94       55.88
#          NJ |         20        2.94       58.82
#          NM |         20        2.94       61.76
#          NY |         20        2.94       64.71
#          OH |         20        2.94       67.65
#          OK |         20        2.94       70.59
#          OR |         20        2.94       73.53
#          PA |         20        2.94       76.47
#          SC |         20        2.94       79.41
#          TN |         20        2.94       82.35
#          TX |         20        2.94       85.29
#          UT |         20        2.94       88.24
#          VA |         20        2.94       91.18
#          WA |         20        2.94       94.12
#          WI |         20        2.94       97.06
#          WV |         20        2.94      100.00
# ------------+-----------------------------------
#       Total |        680      100.00
#
# .

# %%
# %%stata
# frame change default
# // Create link to "working" frame by matching on year
# frlink 1:1 year state, frame(working)
# frget annualPay, from(working)
# Out:
# . frame change default
#
# . // Create link to "working" frame by matching on year
# . frlink 1:1 year state, frame(working)
#   (all observations in frame default matched)
#
# . frget annualPay, from(working)
# (4 missing values generated)
#   (1 variable copied from linked frame)
#
# .

# %%
# %%stata
# // Drop frame link variable
# drop working
# Out:
# . // Drop frame link variable
# . drop working
#
# .

# %%
# %%stata
# // Check data
# list if state=="WA"
# list if state=="TX"
# list if state=="MO"
# Out:
# . // Check data
# . list if state=="WA"
#
#      +------------------------------------+
#      | year   employ~t   state   annual~y |
#      |------------------------------------|
# 481. | 2001      87243      WA      65162 |
# 482. | 2002      75653      WA      71465 |
# 483. | 2003      65274      WA      73460 |
# 484. | 2004      61384      WA      77747 |
# 485. | 2005      65616      WA      84146 |
#      |------------------------------------|
# 486. | 2006      73180      WA      90155 |
# 487. | 2007      80036      WA      86735 |
# 488. | 2008      82932      WA      87114 |
# 489. | 2009      82920      WA      87887 |
# 490. | 2010      80762      WA      91526 |
#      |------------------------------------|
# 491. | 2011      86577      WA      97215 |
# 492. | 2012      94224      WA      96688 |
# 493. | 2013      96012      WA     100105 |
# 494. | 2014      93889      WA     110016 |
# 495. | 2015      93816      WA     107138 |
#      |------------------------------------|
# 496. | 2016      90845      WA     108274 |
# 497. | 2017      83998      WA     113798 |
# 498. | 2018      83879      WA     119650 |
# 499. | 2019      88483      WA     118995 |
# 500. | 2020      80003      WA     116955 |
#      +------------------------------------+
#
# . list if state=="TX"
#
#      +------------------------------------+
#      | year   employ~t   state   annual~y |
#      |------------------------------------|
# 581. | 2001      41037      TX      61136 |
# 582. | 2002      41080      TX      65499 |
# 583. | 2003      46060      TX      66974 |
# 584. | 2004      45986      TX      69589 |
# 585. | 2005      48315      TX      71941 |
#      |------------------------------------|
# 586. | 2006      48993      TX      75925 |
# 587. | 2007      47871      TX      78227 |
# 588. | 2008      48356      TX      80687 |
# 589. | 2009      48141      TX      83928 |
# 590. | 2010      48029      TX      85888 |
#      |------------------------------------|
# 591. | 2011      48391      TX      88167 |
# 592. | 2012      47940      TX      89334 |
# 593. | 2013      47285      TX      93391 |
# 594. | 2014      44698      TX      94995 |
# 595. | 2015      43609      TX      99618 |
#      |------------------------------------|
# 596. | 2016      44639      TX     103503 |
# 597. | 2017      44121      TX     104552 |
# 598. | 2018      46060      TX     108269 |
# 599. | 2019      49412      TX     111737 |
# 600. | 2020      48978      TX     112614 |
#      +------------------------------------+
#
# . list if state=="MO"
#
#      +------------------------------------+
#      | year   employ~t   state   annual~y |
#      |------------------------------------|
# 521. | 2001      13998      MO      63203 |
# 522. | 2002      13556      MO      70430 |
# 523. | 2003      12552      MO      78051 |
# 524. | 2004      15900      MO      76518 |
# 525. | 2005      15452      MO      81340 |
#      |------------------------------------|
# 526. | 2006      15306      MO      90639 |
# 527. | 2007      14560      MO      86164 |
# 528. | 2008      14549      MO      89035 |
# 529. | 2009      14922      MO      87379 |
# 530. | 2010      14657      MO      91617 |
#      |------------------------------------|
# 531. | 2011      14490      MO      97100 |
# 532. | 2012      14235      MO     102881 |
# 533. | 2013      17689      MO     105111 |
# 534. | 2014      17778      MO     111073 |
# 535. | 2015      16778      MO     108757 |
#      |------------------------------------|
# 536. | 2016      16044      MO     108886 |
# 537. | 2017      15814      MO     114566 |
# 538. | 2018      16127      MO     118080 |
# 539. | 2019      17406      MO     115738 |
# 540. | 2020      17814      MO     105995 |
#      +------------------------------------+
#
# .

# %% [markdown]
# ---

# %% [markdown]
# ## Generate Calculated Parameters

# %% [markdown]
# ### Add ln(\*) for *pop*, *employment*, and *wages*

# %%
# %%stata
# generate lnEmployment=ln(employment)
# generate lnAnnualPay = ln(annualPay)
# Out:
# . generate lnEmployment=ln(employment)
# (4 missing values generated)
#
# . generate lnAnnualPay = ln(annualPay)
# (4 missing values generated)
#
# .

# %%
# %%stata
# // Combined QCEW Data
# save "$finalQCEWData", replace
# Out:
# . // Combined QCEW Data
# . save "$finalQCEWData", replace
# file Data/Processed/QCEW/MergedQCEW.dta saved
#
# .

# %% [markdown]
# ## Save Final Data

# %%
# %%capture
# %%stata
frame reset
clear
log close
