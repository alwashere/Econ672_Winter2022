# %% [markdown]
# # Data Cleaning - Census/FRED
#
# Data cleaning for ECON672 Project
# This file aggregates Census Population estimates and
# FRED annual unemployment data.

# %%
# %%capture
# Capture suppresses output to screen
import stata_setup
stata_setup.config("/Applications/Stata 17", "be")

# %%
# %%stata
# /* Define paths for data and output */
# global data "Data"
# global output "Output"
#
# global raw "$data/Raw"
# global fredUnemploy "FRED/Unemployment"
# global pop2000 "US_Census/2000-2010"
# global pop2010 "US_Census/2010-2019"
#
# global rawUnemploy "$raw/$fredUnemploy"
# global rawPop2000 "$raw/$pop2000"
# global rawPop2010 "$raw/$pop2010"
#
# global processed "$data/Processed"
# global processedUnemploy "$processed/$fredUnemploy"
# global processedPop2000 "$processed/$pop2000"
# global processedPop2010 "$processed/$pop2010"
#
# global finalFredData "$processed/FRED/MergedFred.dta"
# global mergedPop2000 "$processed/US_Census/allPop2000.dta"
# global finalCensusData "$processed/US_Census/MergedCensus.dta"
# Out:
# . /* Define paths for data and output */
# . global data "Data"
#
# . global output "Output"
#
# .
# . global raw "$data/Raw"
#
# . global fredUnemploy "FRED/Unemployment"
#
# . global pop2000 "US_Census/2000-2010"
#
# . global pop2010 "US_Census/2010-2019"
#
# .
# . global rawUnemploy "$raw/$fredUnemploy"
#
# . global rawPop2000 "$raw/$pop2000"
#
# . global rawPop2010 "$raw/$pop2010"
#
# .
# . global processed "$data/Processed"
#
# . global processedUnemploy "$processed/$fredUnemploy"
#
# . global processedPop2000 "$processed/$pop2000"
#
# . global processedPop2010 "$processed/$pop2010"
#
# .
# . global finalFredData "$processed/FRED/MergedFred.dta"
#
# . global mergedPop2000 "$processed/US_Census/allPop2000.dta"
#
# . global finalCensusData "$processed/US_Census/MergedCensus.dta"
#
# .

# %%
# %%capture
# %%stata
log using "$output/dataClean-syth-census-fred.log", replace

# %% [markdown]
# ## Import FRED Uemploymen data
# Data is FRED state-level annual unemployment rate, LAUST - series
#
# | i.year | c.lnUnmploy | i.state |
# | --- | ---- | --- |
# | year | ln(unEmploy) |  MO |
# | year | ln(unEmploy) |  WA |

# %% [markdown]
# ## Import  Unemployment Numbers from the States

# %%
# %%stata
# /* Read all the xlsx files into Stata files */
# local fileList: dir "$rawUnemploy" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#     di ">>>Importing data for ", thisState, ": `thisFile'"
#     import excel "$rawUnemploy/`thisFile'", ///
#     sheet("FRED Graph") ///
#     cellrange(A11:B56) ///
#     firstrow ///
#     clear
#
#     /*
#         Change series name to useful variable and
#         create ln(unemployment)
#     */
#     rename LAUST* unemploy
#     label variable ///
#         unemploy "Annual state level unemployment rate (not seasonaly adjusted)"
#     generate lnUnemploy=ln(unemploy)
#     label variable ///
#         lnUnemploy "ln(unemploy)"
#
#     /* Convert Day Month Year time to year */
#     generate year=year(observation_date)
#     drop observation_date
#
#     local dtaFile: di (thisState+".dta")
#     save "$processedUnemploy/`dtaFile'", replace
#
# }
# Out:
# . /* Read all the xlsx files into Stata files */
# . local fileList: dir "$rawUnemploy" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
#   4.
# .     di ">>>Importing data for ", thisState, ": `thisFile'"
#   5.     import excel "$rawUnemploy/`thisFile'", ///
# >     sheet("FRED Graph") ///
# >     cellrange(A11:B56) ///
# >     firstrow ///
# >     clear
#   6.
# .     /*
# >         Change series name to useful variable and
# >         create ln(unemployment)
# >     */
# .     rename LAUST* unemploy
#   7.     label variable ///
# >         unemploy "Annual state level unemployment rate (not seasonaly adjuste
# > d)"
#   8.     generate lnUnemploy=ln(unemploy)
#   9.     label variable ///
# >         lnUnemploy "ln(unemploy)"
#  10.
# .     /* Convert Day Month Year time to year */
# .     generate year=year(observation_date)
#  11.     drop observation_date
#  12.
# .     local dtaFile: di (thisState+".dta")
#  13.     save "$processedUnemploy/`dtaFile'", replace
#  14.
# . }
# >>>Importing data for  GA : GA.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/GA.dta saved
# >>>Importing data for  SC : SC.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/SC.dta saved
# >>>Importing data for  KS : KS.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/KS.dta saved
# >>>Importing data for  IL : IL.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/IL.dta saved
# >>>Importing data for  IN : IN.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/IN.dta saved
# >>>Importing data for  OH : OH.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/OH.dta saved
# >>>Importing data for  NM : NM.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/NM.dta saved
# >>>Importing data for  MA : MA.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/MA.dta saved
# >>>Importing data for  OK : OK.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/OK.dta saved
# >>>Importing data for  NY : NY.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/NY.dta saved
# >>>Importing data for  NJ : NJ.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/NJ.dta saved
# >>>Importing data for  AR : AR.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/AR.dta saved
# >>>Importing data for  WI : WI.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/WI.dta saved
# >>>Importing data for  UT : UT.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/UT.dta saved
# >>>Importing data for  CO : CO.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/CO.dta saved
# >>>Importing data for  MD : MD.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/MD.dta saved
# >>>Importing data for  NH : NH.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/NH.dta saved
# >>>Importing data for  MS : MS.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/MS.dta saved
# >>>Importing data for  MI : MI.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/MI.dta saved
# >>>Importing data for  CT : CT.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/CT.dta saved
# >>>Importing data for  CA : CA.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/CA.dta saved
# >>>Importing data for  VA : VA.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/VA.dta saved
# >>>Importing data for  MO : MO.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/MO.dta saved
# >>>Importing data for  NC : NC.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/NC.dta saved
# >>>Importing data for  AL : AL.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/AL.dta saved
# >>>Importing data for  WV : WV.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/WV.dta saved
# >>>Importing data for  WA : WA.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/WA.dta saved
# >>>Importing data for  AZ : AZ.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/AZ.dta saved
# >>>Importing data for  TN : TN.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/TN.dta saved
# >>>Importing data for  TX : TX.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/TX.dta saved
# >>>Importing data for  OR : OR.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/OR.dta saved
# >>>Importing data for  PA : PA.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/PA.dta saved
# >>>Importing data for  FL : FL.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/FL.dta saved
# >>>Importing data for  KY : KY.xls
# (2 vars, 45 obs)
# file Data/Processed/FRED/Unemployment/KY.dta saved
#
# .

# %%
# %%stata
# /* Append all the State-level Stata files into a single file */
# local fileList: dir "$processedUnemploy" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#
#     /* Special actions for first file */
#     if `i'==1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         use "$processedUnemploy/`thisFile'", clear
#         generate state = thisState
#     }
#
#     /* Actions for all subsequent files */
#     if `i'!=1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         append using "$processedUnemploy/`thisFile'"
#         replace state = thisState if state==""
#     }
#
#     if `i'==`n_files'{
#         /* Drop obs for years prior to 2001 and after 2020*/
#         drop if year<2001
#         drop if year>2020
#         save "$finalFredData", replace
#     }
#
# }
# Out:
# . /* Append all the State-level Stata files into a single file */
# . local fileList: dir "$processedUnemploy" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
# >
#   4.
# .
# .     /* Special actions for first file */
# .     if `i'==1 {
#   5.         di ">>>Importing data for ", thisState, ": `thisFile'"
#   6.         use "$processedUnemploy/`thisFile'", clear
#   7.         generate state = thisState
#   8.     }
#   9.
# .     /* Actions for all subsequent files */
# .     if `i'!=1 {
#  10.         di ">>>Importing data for ", thisState, ": `thisFile'"
#  11.         append using "$processedUnemploy/`thisFile'"
#  12.         replace state = thisState if state==""
#  13.     }
#  14.
# .     if `i'==`n_files'{
#  15.         /* Drop obs for years prior to 2001 and after 2020*/
# .         drop if year<2001
#  16.         drop if year>2020
#  17.         save "$finalFredData", replace
#  18.     }
#  19.
# . }
# >>>Importing data for  GA : GA.dta
# >>>Importing data for  KS : KS.dta
# (45 real changes made)
# >>>Importing data for  IL : IL.dta
# (45 real changes made)
# >>>Importing data for  SC : SC.dta
# (45 real changes made)
# >>>Importing data for  IN : IN.dta
# (45 real changes made)
# >>>Importing data for  NM : NM.dta
# (45 real changes made)
# >>>Importing data for  MA : MA.dta
# (45 real changes made)
# >>>Importing data for  OH : OH.dta
# (45 real changes made)
# >>>Importing data for  NY : NY.dta
# (45 real changes made)
# >>>Importing data for  OK : OK.dta
# (45 real changes made)
# >>>Importing data for  WI : WI.dta
# (45 real changes made)
# >>>Importing data for  AR : AR.dta
# (45 real changes made)
# >>>Importing data for  NJ : NJ.dta
# (45 real changes made)
# >>>Importing data for  MD : MD.dta
# (45 real changes made)
# >>>Importing data for  NH : NH.dta
# (45 real changes made)
# >>>Importing data for  MS : MS.dta
# (45 real changes made)
# >>>Importing data for  CO : CO.dta
# (45 real changes made)
# >>>Importing data for  UT : UT.dta
# (45 real changes made)
# >>>Importing data for  CT : CT.dta
# (45 real changes made)
# >>>Importing data for  MI : MI.dta
# (45 real changes made)
# >>>Importing data for  VA : VA.dta
# (45 real changes made)
# >>>Importing data for  CA : CA.dta
# (45 real changes made)
# >>>Importing data for  AZ : AZ.dta
# (45 real changes made)
# >>>Importing data for  WV : WV.dta
# (45 real changes made)
# >>>Importing data for  WA : WA.dta
# (45 real changes made)
# >>>Importing data for  AL : AL.dta
# (45 real changes made)
# >>>Importing data for  MO : MO.dta
# (45 real changes made)
# >>>Importing data for  NC : NC.dta
# (45 real changes made)
# >>>Importing data for  OR : OR.dta
# (45 real changes made)
# >>>Importing data for  TX : TX.dta
# (45 real changes made)
# >>>Importing data for  TN : TN.dta
# (45 real changes made)
# >>>Importing data for  FL : FL.dta
# (45 real changes made)
# >>>Importing data for  PA : PA.dta
# (45 real changes made)
# >>>Importing data for  KY : KY.dta
# (45 real changes made)
# (850 observations deleted)
# (0 observations deleted)
# file Data/Processed/FRED/MergedFred.dta saved
#
# .

# %%
# %%stata
# describe
# summarize
# tab state
# Out:
# . describe
#
# Contains data from Data/Processed/FRED/MergedFred.dta
#  Observations:           680
#     Variables:             4                  5 Feb 2022 17:31
# -------------------------------------------------------------------------------
# Variable      Storage   Display    Value
#     name         type    format    label      Variable label
# -------------------------------------------------------------------------------
# unemploy        double  %10.0g                Annual state level unemployment
#                                                 rate (not seasonaly adjusted)
# lnUnemploy      float   %9.0g                 ln(unemploy)
# year            float   %9.0g
# state           str2    %9s
# -------------------------------------------------------------------------------
# Sorted by:
#
# . summarize
#
#     Variable |        Obs        Mean    Std. dev.       Min        Max
# -------------+---------------------------------------------------------
#     unemploy |        680    5.957941    1.964905        2.5       13.1
#   lnUnemploy |        680    1.732401    .3236413   .9162908   2.572612
#         year |        680      2010.5    5.770526       2001       2020
#        state |          0
#
# . tab state
#
#       state |      Freq.     Percent        Cum.
# ------------+-----------------------------------
#          AL |         20        2.94        2.94
#          AR |         20        2.94        5.88
#          AZ |         20        2.94        8.82
#          CA |         20        2.94       11.76
#          CO |         20        2.94       14.71
#          CT |         20        2.94       17.65
#          FL |         20        2.94       20.59
#          GA |         20        2.94       23.53
#          IL |         20        2.94       26.47
#          IN |         20        2.94       29.41
#          KS |         20        2.94       32.35
#          KY |         20        2.94       35.29
#          MA |         20        2.94       38.24
#          MD |         20        2.94       41.18
#          MI |         20        2.94       44.12
#          MO |         20        2.94       47.06
#          MS |         20        2.94       50.00
#          NC |         20        2.94       52.94
#          NH |         20        2.94       55.88
#          NJ |         20        2.94       58.82
#          NM |         20        2.94       61.76
#          NY |         20        2.94       64.71
#          OH |         20        2.94       67.65
#          OK |         20        2.94       70.59
#          OR |         20        2.94       73.53
#          PA |         20        2.94       76.47
#          SC |         20        2.94       79.41
#          TN |         20        2.94       82.35
#          TX |         20        2.94       85.29
#          UT |         20        2.94       88.24
#          VA |         20        2.94       91.18
#          WA |         20        2.94       94.12
#          WI |         20        2.94       97.06
#          WV |         20        2.94      100.00
# ------------+-----------------------------------
#       Total |        680      100.00
#
# .

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## US Census Data Population Estimates
# There are two main datasets:
# + 2000-2010 is contained in a single file per state
# + 2010-2019 is contained in a single file that includes all the states

# %% [markdown]
# ### US Census 2000-2010

# %%
# %%stata
# /* Read all the xlsx files into Stata files */
# local fileList: dir "$rawPop2000" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#     di ">>>Importing data for ", thisState, ": `thisFile'"
#     import excel "$rawPop2000/`thisFile'", ///
#     sheet("ST-EST00INT-02") ///
#     cellrange(A4:N5) ///
#     firstrow ///
#     clear
#
#     /*  Drop columns */
#     drop A B M N
#
#     /* State ID */
#     generate state = thisState
#
#     /* Rename columns to prep for reshape */
#     scalar yearCount = 2000
#         foreach var of varlist C-L{
#             local j: display int(yearCount)
#             rename `var' pop`j'
#             scalar yearCount = yearCount + 1
#         }
#
#     /*
#         Reshape the data to a long format
#     */
#     reshape long pop, i(state) j(year)
#
#     /*
#     Convert to Strings by ignoring the ",".
#       Raw data is formated with comma separator for thousands
#       and millions.
#     */
#     destring(pop), replace ignore(",")
#     label variable pop "US Census Population Estimate"
#
#
#     local dtaFile: di (thisState+".dta")
#     save "$processedPop2000/`dtaFile'", replace
#
# }
# Out:
# . /* Read all the xlsx files into Stata files */
# . local fileList: dir "$rawPop2000" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
#   4.
# .     di ">>>Importing data for ", thisState, ": `thisFile'"
#   5.     import excel "$rawPop2000/`thisFile'", ///
# >     sheet("ST-EST00INT-02") ///
# >     cellrange(A4:N5) ///
# >     firstrow ///
# >     clear
#   6.
# .     /*  Drop columns */
# .     drop A B M N
#   7.
# .     /* State ID */
# .     generate state = thisState
#   8.
# .     /* Rename columns to prep for reshape */
# .     scalar yearCount = 2000
#   9.         foreach var of varlist C-L{
#  10.             local j: display int(yearCount)
#  11.             rename `var' pop`j'
#  12.             scalar yearCount = yearCount + 1
#  13.         }
#  14.
# .     /*
# >         Reshape the data to a long format
# >     */
# .     reshape long pop, i(state) j(year)
#  15.
# .     /*
# >     Convert to Strings by ignoring the ",".
# >       Raw data is formated with comma separator for thousands
# >       and millions.
# >     */
# .     destring(pop), replace ignore(",")
#  16.     label variable pop "US Census Population Estimate"
#  17.
# .
# .     local dtaFile: di (thisState+".dta")
#  18.     save "$processedPop2000/`dtaFile'", replace
#  19.
# . }
# >>>Importing data for  GA : GA.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/GA.dta saved
# >>>Importing data for  SC : SC.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/SC.dta saved
# >>>Importing data for  KS : KS.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/KS.dta saved
# >>>Importing data for  IL : IL.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/IL.dta saved
# >>>Importing data for  IN : IN.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/IN.dta saved
# >>>Importing data for  OH : OH.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/OH.dta saved
# >>>Importing data for  NM : NM.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/NM.dta saved
# >>>Importing data for  MA : MA.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/MA.dta saved
# >>>Importing data for  OK : OK.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/OK.dta saved
# >>>Importing data for  NY : NY.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/NY.dta saved
# >>>Importing data for  NJ : NJ.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/NJ.dta saved
# >>>Importing data for  AR : AR.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/AR.dta saved
# >>>Importing data for  WI : WI.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/WI.dta saved
# >>>Importing data for  UT : UT.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/UT.dta saved
# >>>Importing data for  CO : CO.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/CO.dta saved
# >>>Importing data for  MD : MD.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/MD.dta saved
# >>>Importing data for  NH : NH.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/NH.dta saved
# >>>Importing data for  MS : MS.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/MS.dta saved
# >>>Importing data for  MI : MI.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/MI.dta saved
# >>>Importing data for  CT : CT.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/CT.dta saved
# >>>Importing data for  CA : CA.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/CA.dta saved
# >>>Importing data for  VA : VA.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/VA.dta saved
# >>>Importing data for  MO : MO.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/MO.dta saved
# >>>Importing data for  NC : NC.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/NC.dta saved
# >>>Importing data for  AL : AL.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/AL.dta saved
# >>>Importing data for  WV : WV.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/WV.dta saved
# >>>Importing data for  WA : WA.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/WA.dta saved
# >>>Importing data for  AZ : AZ.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/AZ.dta saved
# >>>Importing data for  TN : TN.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/TN.dta saved
# >>>Importing data for  TX : TX.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/TX.dta saved
# >>>Importing data for  OR : OR.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/OR.dta saved
# >>>Importing data for  DE : DE.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/DE.dta saved
# >>>Importing data for  PA : PA.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/PA.dta saved
# >>>Importing data for  FL : FL.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/FL.dta saved
# >>>Importing data for  ID : ID.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/ID.dta saved
# >>>Importing data for  KY : KY.xls
# (14 vars, 1 obs)
# (j = 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations                1   ->   10
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2000 pop2001 ... pop2009   ->   pop
# -----------------------------------------------------------------------------
# pop already numeric; no replace
# file Data/Processed/US_Census/2000-2010/KY.dta saved
#
# .

# %%
# %%stata
# /* Append all the State-level Stata files into a single file */
# local fileList: dir "$processedPop2000" files "*"
# local n_files: word count `fileList'
#
# forval i=1/`n_files' {
#     local thisFile `: word `i' of `fileList''
#     scalar thisState = substr("`thisFile'", 1, 2)
#
#
#     /* Special actions for first file */
#     if `i'==1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         use "$processedPop2000/`thisFile'", clear
#     }
#
#     /* Actions for all subsequent files */
#     if `i'!=1 {
#         di ">>>Importing data for ", thisState, ": `thisFile'"
#         append using "$processedPop2000/`thisFile'"
#     }
#
#     if `i'==`n_files'{
#         save "$mergedPop2000", replace
#     }
#
# }
# Out:
# . /* Append all the State-level Stata files into a single file */
# . local fileList: dir "$processedPop2000" files "*"
#
# . local n_files: word count `fileList'
#
# .
# . forval i=1/`n_files' {
#   2.     local thisFile `: word `i' of `fileList''
#   3.     scalar thisState = substr("`thisFile'", 1, 2)
# >
#   4.
# .
# .     /* Special actions for first file */
# .     if `i'==1 {
#   5.         di ">>>Importing data for ", thisState, ": `thisFile'"
#   6.         use "$processedPop2000/`thisFile'", clear
#   7.     }
#   8.
# .     /* Actions for all subsequent files */
# .     if `i'!=1 {
#   9.         di ">>>Importing data for ", thisState, ": `thisFile'"
#  10.         append using "$processedPop2000/`thisFile'"
#  11.     }
#  12.
# .     if `i'==`n_files'{
#  13.         save "$mergedPop2000", replace
#  14.     }
#  15.
# . }
# >>>Importing data for  GA : GA.dta
# >>>Importing data for  KS : KS.dta
# >>>Importing data for  IL : IL.dta
# >>>Importing data for  SC : SC.dta
# >>>Importing data for  IN : IN.dta
# >>>Importing data for  NM : NM.dta
# >>>Importing data for  MA : MA.dta
# >>>Importing data for  OH : OH.dta
# >>>Importing data for  NY : NY.dta
# >>>Importing data for  OK : OK.dta
# >>>Importing data for  WI : WI.dta
# >>>Importing data for  AR : AR.dta
# >>>Importing data for  NJ : NJ.dta
# >>>Importing data for  MD : MD.dta
# >>>Importing data for  NH : NH.dta
# >>>Importing data for  MS : MS.dta
# >>>Importing data for  CO : CO.dta
# >>>Importing data for  UT : UT.dta
# >>>Importing data for  CT : CT.dta
# >>>Importing data for  MI : MI.dta
# >>>Importing data for  VA : VA.dta
# >>>Importing data for  CA : CA.dta
# >>>Importing data for  AZ : AZ.dta
# >>>Importing data for  WV : WV.dta
# >>>Importing data for  WA : WA.dta
# >>>Importing data for  AL : AL.dta
# >>>Importing data for  MO : MO.dta
# >>>Importing data for  NC : NC.dta
# >>>Importing data for  OR : OR.dta
# >>>Importing data for  TX : TX.dta
# >>>Importing data for  TN : TN.dta
# >>>Importing data for  FL : FL.dta
# >>>Importing data for  PA : PA.dta
# >>>Importing data for  DE : DE.dta
# >>>Importing data for  ID : ID.dta
# >>>Importing data for  KY : KY.dta
# file Data/Processed/US_Census/allPop2000.dta saved
#
# .

# %%
# %%stata
# list in 1/10
# Out:
#      +------------------------+
#      | state   year       pop |
#      |------------------------|
#   1. |    GA   2000   8227303 |
#   2. |    GA   2001   8377038 |
#   3. |    GA   2002   8508256 |
#   4. |    GA   2003   8622793 |
#   5. |    GA   2004   8769252 |
#      |------------------------|
#   6. |    GA   2005   8925922 |
#   7. |    GA   2006   9155813 |
#   8. |    GA   2007   9349988 |
#   9. |    GA   2008   9504843 |
#  10. |    GA   2009   9620846 |
#      +------------------------+

# %% [markdown]
# ### US Census Population Estimates 2010-2019

# %%
# %%stata
# import excel "$rawPop2010/2010_2019_PopEst.xlsx", ///
#     sheet("Data") ///
#     cellrange(A2:M54) ///
#     firstrow ///
#     clear
#
# /*
#     Drop B which is"2010 Census population"
#     Drop C which is the estimate base
#     Data will only include population estimates
#       July 2010- July 2019
# */
# drop Population C
# Out:
# . import excel "$rawPop2010/2010_2019_PopEst.xlsx", ///
# >     sheet("Data") ///
# >     cellrange(A2:M54) ///
# >     firstrow ///
# >     clear
# (13 vars, 52 obs)
#
# .
# . /*
# >     Drop B which is"2010 Census population"
# >     Drop C which is the estimate base
# >     Data will only include population estimates
# >       July 2010- July 2019
# > */
# . drop Population C
#
# .

# %%
# %%stata
# // Rename each of the population for reshape cmd
# scalar i = 2010
# foreach var of varlist D-M{
#     local j: display int(i)
#     rename `var' pop`j'
#     scalar i = i + 1
# }
# rename GeographicAreaName stateName
# Out:
# . // Rename each of the population for reshape cmd
# . scalar i = 2010
#
# . foreach var of varlist D-M{
#   2.     local j: display int(i)
#   3.     rename `var' pop`j'
#   4.     scalar i = i + 1
#   5. }
#
# . rename GeographicAreaName stateName
#
# .

# %%
# %%stata
# list in 1
# merge 1:1 stateName using "$raw/StateCodes.dta", ///
#     keepusing(state)
# list in 1
# Out:
# . list in 1
#
#      +----------------------------------------------------------------------+
#   1. | stateN~e |   pop2010 |   pop2011 |   pop2012 |   pop2013 |   pop2014 |
#      |  Alabama | 4,785,437 | 4,799,069 | 4,815,588 | 4,830,081 | 4,841,799 |
#      |----------------------------------------------------------------------|
#      |    pop2015  |    pop2016  |    pop2017  |    pop2018  |    pop2019   |
#      |  4,852,347  |  4,863,525  |  4,874,486  |  4,887,681  |  4,903,185   |
#      +----------------------------------------------------------------------+
#
# . merge 1:1 stateName using "$raw/StateCodes.dta", ///
# >     keepusing(state)
#
#     Result                      Number of obs
#     -----------------------------------------
#     Not matched                             0
#     Matched                                52  (_merge==3)
#     -----------------------------------------
#
# . list in 1
#
#      +----------------------------------------------------------------------+
#   1. | stateN~e |   pop2010 |   pop2011 |   pop2012 |   pop2013 |   pop2014 |
#      |  Alabama | 4,785,437 | 4,799,069 | 4,815,588 | 4,830,081 | 4,841,799 |
#      |----------------------------------------------------------------------|
#      |   pop2015 |   pop2016 |   pop2017 |   pop2018  |   pop2019  | state  |
#      | 4,852,347 | 4,863,525 | 4,874,486 | 4,887,681  | 4,903,185  |    AL  |
#      |----------------------------------------------------------------------|
#      |                                  _merge                              |
#      |                             Matched (3)                              |
#      +----------------------------------------------------------------------+
#
# .

# %%
# %%stata
# drop stateName _merge

# %%
# %%stata
# reshape long pop, i(state) j(year)
# Out:
# (j = 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019)
#
# Data                               Wide   ->   Long
# -----------------------------------------------------------------------------
# Number of observations               52   ->   520
# Number of variables                  11   ->   3
# j variable (10 values)                    ->   year
# xij variables:
#             pop2010 pop2011 ... pop2019   ->   pop
# -----------------------------------------------------------------------------

# %%
# %%stata
# list in 1
# Out:
#      +------------------------+
#      | state   year       pop |
#      |------------------------|
#   1. |    AK   2010   713,910 |
#      +------------------------+

# %%
# %%stata
# /*
# Convert to Strings by ignoring the ",".
#   Raw data is formated with comma separator for thousands
#   and millions.
# */
# destring(pop), replace ignore(",")
# label variable pop "US Census Population Estimate"
# Out:
# . /*
# > Convert to Strings by ignoring the ",".
# >   Raw data is formated with comma separator for thousands
# >   and millions.
# > */
# . destring(pop), replace ignore(",")
# pop: character , removed; replaced as long
#
# . label variable pop "US Census Population Estimate"
#
# .

# %% [markdown]
# ---

# %% [markdown]
# ## Merge 2000-2009 and 2010-2019 Census Data

# %%
# %%stata
# append using "$mergedPop2000"

# %%
# %%stata
# sort state year
# summarize
# list if state=="MO"
# list if state=="CA"
# Out:
# . sort state year
#
# . summarize
#
#     Variable |        Obs        Mean    Std. dev.       Min        Max
# -------------+---------------------------------------------------------
#        state |          0
#         year |        880    2010.409    5.697406       2000       2019
#          pop |        880     6727482     6993185     564487   3.95e+07
#
# . list if state=="MO"
#
#      +------------------------+
#      | state   year       pop |
#      |------------------------|
# 411. |    MO   2000   5607285 |
# 412. |    MO   2001   5641142 |
# 413. |    MO   2002   5674825 |
# 414. |    MO   2003   5709403 |
# 415. |    MO   2004   5747741 |
#      |------------------------|
# 416. |    MO   2005   5790300 |
# 417. |    MO   2006   5842704 |
# 418. |    MO   2007   5887612 |
# 419. |    MO   2008   5923916 |
# 420. |    MO   2009   5961088 |
#      |------------------------|
# 421. |    MO   2010   5995974 |
# 422. |    MO   2011   6010275 |
# 423. |    MO   2012   6024367 |
# 424. |    MO   2013   6040715 |
# 425. |    MO   2014   6056202 |
#      |------------------------|
# 426. |    MO   2015   6071732 |
# 427. |    MO   2016   6087135 |
# 428. |    MO   2017   6106670 |
# 429. |    MO   2018   6121623 |
# 430. |    MO   2019   6137428 |
#      +------------------------+
#
# . list if state=="CA"
#
#      +-------------------------+
#      | state   year        pop |
#      |-------------------------|
#  71. |    CA   2000   33987977 |
#  72. |    CA   2001   34479458 |
#  73. |    CA   2002   34871843 |
#  74. |    CA   2003   35253159 |
#  75. |    CA   2004   35574576 |
#      |-------------------------|
#  76. |    CA   2005   35827943 |
#  77. |    CA   2006   36021202 |
#  78. |    CA   2007   36250311 |
#  79. |    CA   2008   36604337 |
#  80. |    CA   2009   36961229 |
#      |-------------------------|
#  81. |    CA   2010   37319502 |
#  82. |    CA   2011   37638369 |
#  83. |    CA   2012   37948800 |
#  84. |    CA   2013   38260787 |
#  85. |    CA   2014   38596972 |
#      |-------------------------|
#  86. |    CA   2015   38918045 |
#  87. |    CA   2016   39167117 |
#  88. |    CA   2017   39358497 |
#  89. |    CA   2018   39461588 |
#  90. |    CA   2019   39512223 |
#      +-------------------------+
#
# .

# %% [markdown]
# ---

# %% [markdown]
# ## Generate Calculated Parameters

# %% [markdown]
# ### Add ln(pop)

# %%
# %%stata
# generate lnPop=ln(pop)

# %% [markdown]
# ## Save Final Census Data

# %%
# %%stata
# save $finalCensusData, replace
# Out:
# file Data/Processed/US_Census/MergedCensus.dta saved

# %%
# %%capture
# %%stata
clear
log close
