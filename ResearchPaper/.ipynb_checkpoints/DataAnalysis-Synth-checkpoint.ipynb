# %% [markdown]
# # Synthetic Controls Comparison Data Analysis

# %%
# %%capture
# Capture suppresses output to screen
import stata_setup
stata_setup.config("/Applications/Stata 17", "be")

# %%
# %%stata
# /* Define input and output paths */
# global data "Data"
# global output "Output"
# global graphs "$output/Graphs"
# global tables "$output/Tables"
#
# global processed "$data/Processed"
#
# global finalSynthData "$processed/finalSynth.dta"
# Out:
# . /* Define input and output paths */
# . global data "Data"
#
# . global output "Output"
#
# . global graphs "$output/Graphs"
#
# . global tables "$output/Tables"
#
# .
# . global processed "$data/Processed"
#
# .
# . global finalSynthData "$processed/finalSynth.dta"
#
# .

# %%
# %%capture
# %%stata
log using "$output/analysis-Syth.log", replace

# %% [markdown]
# ## Read in Master Data File

# %%
# %%stata
# use "$finalSynthData", clear
# describe
# Out:
# . use "$finalSynthData", clear
#
# . describe
#
# Contains data from Data/Processed/finalSynth.dta
#  Observations:           646
#     Variables:            24                  5 Feb 2022 19:04
# -------------------------------------------------------------------------------
# Variable      Storage   Display    Value
#     name         type    format    label      Variable label
# -------------------------------------------------------------------------------
# year            float   %10.0g                Year
# employment      long    %10.0g                Annual Reported Employment (NAICS
#                                                 3364)
# state           str2    %9s
# annualPay       long    %10.0g                Average Annual Pay (USD) (NAICS
#                                                 3364)
# lnEmployment    float   %9.0g
# lnAnnualPay     float   %9.0g
# unemploy        double  %10.0g                Annual state level unemployment
#                                                 rate (not seasonaly adjusted)
# lnUnemploy      float   %9.0g                 ln(unemploy)
# pop             long    %10.0g                US Census Population Estimate
# lnPop           float   %9.0g
# fips            byte    %10.0g                fips State Code
# postIncentive   float   %9.0g                 =1 if year >=2014
# t_0             float   %9.0g
# t_lag4          float   %9.0g
# t_lag3          float   %9.0g
# t_lag2          float   %9.0g
# t_lag1          float   %9.0g
# t_lag0          float   %9.0g
# t_lead1         float   %9.0g
# t_lead2         float   %9.0g
# t_lead3         float   %9.0g
# t_lead4         float   %9.0g
# wa              float   %9.0g                 =1 if the state is WA
# treated         float   %9.0g                 =1 if after 2014 and in WA
# -------------------------------------------------------------------------------
# Sorted by: fips  year
#
# .

# %% [markdown]
# ## Evaluate missing values in the data

# %%
# %%stata
# misstable summarize employment annualPay pop unemploy
# Out:
#                                                              Obs<.
#                                                 +------------------------------
#                |                                | Unique
#       Variable |     Obs=.     Obs>.     Obs<.  | values        Min         Max
#   -------------+--------------------------------+------------------------------
#     employment |         4                 642  |   >500        452       96012
#      annualPay |         4                 642  |   >500      34951      138768
#   -----------------------------------------------------------------------------

# %%
# %%stata
# list year state employment annualPay ///
#     if employment==. | annualPay==.
# Out:
# . list year state employment annualPay ///
# >     if employment==. | annualPay==.
#
#      +------------------------------------+
#      | year   state   employ~t   annual~y |
#      |------------------------------------|
# 495. | 2001      SC          .          . |
# 496. | 2002      SC          .          . |
# 497. | 2003      SC          .          . |
# 498. | 2004      SC          .          . |
#      +------------------------------------+
#
# .

# %%
# %%stata
# list year employment annualPay if state=="SC"
# Out:
#      +----------------------------+
#      | year   employ~t   annual~y |
#      |----------------------------|
# 495. | 2001          .          . |
# 496. | 2002          .          . |
# 497. | 2003          .          . |
# 498. | 2004          .          . |
# 499. | 2005        452      61448 |
#      |----------------------------|
# 500. | 2006        515      63420 |
# 501. | 2007        866      67915 |
# 502. | 2008       1365      66607 |
# 503. | 2009       1917      68722 |
# 504. | 2010       2993      72933 |
#      |----------------------------|
# 505. | 2011       4534      76650 |
# 506. | 2012       5867      74753 |
# 507. | 2013       6531      80758 |
# 508. | 2014       7002      91915 |
# 509. | 2015       7340      86881 |
#      |----------------------------|
# 510. | 2016       7920      86006 |
# 511. | 2017       7631      86249 |
# 512. | 2018       7178      93363 |
# 513. | 2019       7381     100039 |
#      +----------------------------+

# %% [markdown]
# ## Drop data prior to 2001-2004
# South Carolina had not significant NAICS 3364 industry prior to 2005 but has
# as significant industry in period afterwards.
#
# Treatment period of interest is 2014.

# %%
# %%stata
# drop if year < 2005
# Out:
# (136 observations deleted)

# %% [markdown]
# ## Generate Summary Statistics for WA

# %%
# %%stata
# estpost summarize employment annualPay unemploy pop if state=="WA", quietly
# eststo waSum
#
# /* For Display */
# esttab waSum, ///
#     noobs nonumbers ///
#     cells( (mean(label("Mean")) min(label("Min")) max(label("Max")) ///
#             count(label("Num Obs"))) ///
#           (sd(par label("SD")) ) ) ///
#     coeflabels(employment "Annual Employment" ///
#               annualPay "Annual Pay" ///
#               unemploy "Annual Unemployment Rate" ///
#               pop "Est Population") ///
#     mtitles("WA") ///
#     addnotes("Standard Deviations in paranthesis" "NAICS 3364 for years 2005-2019")
#
# /* For Ouput */
# esttab waSum using $tables/waSum.tex, ///
#     replace ///
#     noobs nonumbers ///
#     cells( (mean(label("Mean")) min(label("Min")) max(label("Max")) ///
#             count(label("Num Obs"))) ///
#           (sd(par label("SD")) ) ) ///
#     coeflabels(employment "Annual Employment" ///
#               annualPay "Annual Pay" ///
#               unemploy "Annual Unemployment Rate" ///
#               pop "Est Population") ///
#     mtitles("WA") ///
#     addnotes("Standard Deviations in paranthesis" "NAICS 3364 for years 2005-2019")
# Out:
# . estpost summarize employment annualPay unemploy pop if state=="WA", quietly
#
# . eststo waSum
#
# .
# . /* For Display */
# . esttab waSum, ///
# >     noobs nonumbers ///
# >     cells( (mean(label("Mean")) min(label("Min")) max(label("Max")) ///
# >             count(label("Num Obs"))) ///
# >           (sd(par label("SD")) ) ) ///
# >     coeflabels(employment "Annual Employment" ///
# >               annualPay "Annual Pay" ///
# >               unemploy "Annual Unemployment Rate" ///
# >               pop "Est Population") ///
# >     mtitles("WA") ///
# >     addnotes("Standard Deviations in paranthesis" "NAICS 3364 for years 2005-
# > 2019")
#
# ----------------------------------------------------------------
#                        WA
#                   Mean/SD          Min          Max      Num Obs
# ----------------------------------------------------------------
# Annual Emp~t      85144.6        65616        96012           15
#                  (8368.6)
# Annual Pay        99962.8        84146       119650           15
#                 (12202.4)
# Annual Une~e     6.013333          4.1          9.1           15
#                (1.632206)
# Est Popula~n      6921667      6257305      7614893           15
#                (422928.6)
# ----------------------------------------------------------------
# Standard Deviations in paranthesis
# NAICS 3364 for years 2005-2019
#
# .
# . /* For Ouput */
# . esttab waSum using $tables/waSum.tex, ///
# >     replace ///
# >     noobs nonumbers ///
# >     cells( (mean(label("Mean")) min(label("Min")) max(label("Max")) ///
# >             count(label("Num Obs"))) ///
# >           (sd(par label("SD")) ) ) ///
# >     coeflabels(employment "Annual Employment" ///
# >               annualPay "Annual Pay" ///
# >               unemploy "Annual Unemployment Rate" ///
# >               pop "Est Population") ///
# >     mtitles("WA") ///
# >     addnotes("Standard Deviations in paranthesis" "NAICS 3364 for years 2005-
# > 2019")
# (output written to Output/Tables/waSum.tex)
#
# .

# %% [markdown]
# ---

# %% [markdown]
# ## Run synthetic control analysis

# %%
# %%stata
# list fips state if state=="WA"
# Out:
#      +--------------+
#      | fips   state |
#      |--------------|
# 466. |   53      WA |
# 467. |   53      WA |
# 468. |   53      WA |
# 469. |   53      WA |
# 470. |   53      WA |
#      |--------------|
# 471. |   53      WA |
# 472. |   53      WA |
# 473. |   53      WA |
# 474. |   53      WA |
# 475. |   53      WA |
#      |--------------|
# 476. |   53      WA |
# 477. |   53      WA |
# 478. |   53      WA |
# 479. |   53      WA |
# 480. |   53      WA |
#      +--------------+

# %%
# %%stata
# /* WA State is the treatment state.  WA is fips==53 */
# synth lnEmployment ///
#     lnEmployment(2010) lnEmployment(2011) lnEmployment(2012) lnEmployment(2013) ///
#     lnAnnualPay(2010) lnAnnualPay(2011) lnAnnualPay(2012) lnAnnualPay(2013) ///
#     lnUnemploy(2010) lnUnemploy(2011) lnUnemploy(2012) lnUnemploy(2013) ///
#     lnPop(2010) lnPop(2011) lnPop(2012) lnPop(2013), ///
#     trunit(53) trperiod(2014) unitnames(state) ///
#     msperiod(2005(1)2013) resultsperiod(2005(1)2019) replace figure
# Out:
# . /* WA State is the treatment state.  WA is fips==53 */
# . synth lnEmployment ///
# >     lnEmployment(2010) lnEmployment(2011) lnEmployment(2012) lnEmployment(201
# > 3) ///
# >     lnAnnualPay(2010) lnAnnualPay(2011) lnAnnualPay(2012) lnAnnualPay(2013) /
# > //
# >     lnUnemploy(2010) lnUnemploy(2011) lnUnemploy(2012) lnUnemploy(2013) ///
# >     lnPop(2010) lnPop(2011) lnPop(2012) lnPop(2013), ///
# >     trunit(53) trperiod(2014) unitnames(state) ///
# >     msperiod(2005(1)2013) resultsperiod(2005(1)2019) replace figure
# -------------------------------------------------------------------------------
# Synthetic Control Method for Comparative Case Studies
# -------------------------------------------------------------------------------
#
# First Step: Data Setup
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Data Setup successful
# -------------------------------------------------------------------------------
#                 Treated Unit: WA
#                Control Units: AL, AZ, AR, CA, CO, CT, FL, GA, IL, IN, KS, KY,
#                               MD, MA, MI, MS, MO, NH, NJ, NM, NY, NC, OH, OK,
#                               OR, PA, SC, TN, TX, UT, VA, WV, WI
# -------------------------------------------------------------------------------
#           Dependent Variable: lnEmployment
#   MSPE minimized for periods: 2005 2006 2007 2008 2009 2010 2011 2012 2013
# Results obtained for periods: 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#                               2015 2016 2017 2018 2019
# -------------------------------------------------------------------------------
#                   Predictors: lnEmployment(2010) lnEmployment(2011)
#                               lnEmployment(2012) lnEmployment(2013)
#                               lnAnnualPay(2010) lnAnnualPay(2011)
#                               lnAnnualPay(2012) lnAnnualPay(2013)
#                               lnUnemploy(2010) lnUnemploy(2011)
#                               lnUnemploy(2012) lnUnemploy(2013) lnPop(2010)
#                               lnPop(2011) lnPop(2012) lnPop(2013)
# -------------------------------------------------------------------------------
# Unless period is specified
# predictors are averaged over: 2005 2006 2007 2008 2009 2010 2011 2012 2013
# -------------------------------------------------------------------------------
#
# Second Step: Run Optimization
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Optimization done
# -------------------------------------------------------------------------------
#
# Third Step: Obtain Results
# -------------------------------------------------------------------------------
# Loss: Root Mean Squared Prediction Error
#
# ---------------------
#    RMSPE |  .6144402
# ---------------------
# -------------------------------------------------------------------------------
# Unit Weights:
#
# -----------------------
#     Co_No | Unit_Weight
# ----------+------------
#        AL |           0
#        AZ |           0
#        AR |           0
#        CA |        .336
#        CO |           0
#        CT |           0
#        FL |           0
#        GA |           0
#        IL |           0
#        IN |           0
#        KS |        .664
#        KY |           0
#        MD |           0
#        MA |           0
#        MI |           0
#        MS |           0
#        MO |           0
#        NH |           0
#        NJ |           0
#        NM |           0
#        NY |           0
#        NC |           0
#        OH |           0
#        OK |           0
#        OR |           0
#        PA |           0
#        SC |           0
#        TN |           0
#        TX |           0
#        UT |           0
#        VA |           0
#        WV |           0
#        WI |           0
# -----------------------
# -------------------------------------------------------------------------------
# Predictor Balance:
#
# ------------------------------------------------------
#                                |   Treated  Synthetic
# -------------------------------+----------------------
#             lnEmployment(2010) |  11.29926   10.64695
#             lnEmployment(2011) |  11.36879   10.64677
#             lnEmployment(2012) |  11.45343   10.64716
#             lnEmployment(2013) |  11.47223   10.63843
#              lnAnnualPay(2010) |  11.42438   11.25237
#              lnAnnualPay(2011) |  11.48468   11.29486
#              lnAnnualPay(2012) |  11.47924   11.29208
#              lnAnnualPay(2013) |  11.51398   11.30556
#               lnUnemploy(2010) |  2.208274   2.140729
#               lnUnemploy(2011) |  2.140066   2.064699
#               lnUnemploy(2012) |   2.04122   1.945732
#               lnUnemploy(2013) |   1.88707   1.845625
#                    lnPop(2010) |  15.72399   15.72899
#                    lnPop(2011) |  15.73634   15.73441
#                    lnPop(2012) |  15.74661   15.74087
#                    lnPop(2013) |  15.75626   15.74545
# ------------------------------------------------------
# -------------------------------------------------------------------------------
#
# .

# %%
# %%stata
# /* Rename Graph */
# graph rename Graph synthWaEmployment, replace
#
# /*  Show the graph from the command above */
# graph display
# Out:
# . /* Rename Graph */
# . graph rename Graph synthWaEmployment, replace
# (note: graph synthWaEmployment not found)
#
# .
# . /*  Show the graph from the command above */
# . graph display
#
# .

# %%
# %%stata
# synth lnAnnualPay ///
#     lnEmployment(2010) lnEmployment(2011) lnEmployment(2012) lnEmployment(2013) ///
#     lnAnnualPay(2010) lnAnnualPay(2011) lnAnnualPay(2012) lnAnnualPay(2013) ///
#     lnUnemploy(2010) lnUnemploy(2011) lnUnemploy(2012) lnUnemploy(2013) ///
#     lnPop(2010) lnPop(2011) lnPop(2012) lnPop(2013), ///
#     trunit(53) trperiod(2014) unitnames(state) ///
#     msperiod(2005(1)2013) resultsperiod(2005(1)2019) ///
#     replace ///
#     figure
# Out:
# . synth lnAnnualPay ///
# >     lnEmployment(2010) lnEmployment(2011) lnEmployment(2012) lnEmployment(201
# > 3) ///
# >     lnAnnualPay(2010) lnAnnualPay(2011) lnAnnualPay(2012) lnAnnualPay(2013) /
# > //
# >     lnUnemploy(2010) lnUnemploy(2011) lnUnemploy(2012) lnUnemploy(2013) ///
# >     lnPop(2010) lnPop(2011) lnPop(2012) lnPop(2013), ///
# >     trunit(53) trperiod(2014) unitnames(state) ///
# >     msperiod(2005(1)2013) resultsperiod(2005(1)2019) ///
# >     replace ///
# >     figure
# -------------------------------------------------------------------------------
# Synthetic Control Method for Comparative Case Studies
# -------------------------------------------------------------------------------
#
# First Step: Data Setup
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Data Setup successful
# -------------------------------------------------------------------------------
#                 Treated Unit: WA
#                Control Units: AL, AZ, AR, CA, CO, CT, FL, GA, IL, IN, KS, KY,
#                               MD, MA, MI, MS, MO, NH, NJ, NM, NY, NC, OH, OK,
#                               OR, PA, SC, TN, TX, UT, VA, WV, WI
# -------------------------------------------------------------------------------
#           Dependent Variable: lnAnnualPay
#   MSPE minimized for periods: 2005 2006 2007 2008 2009 2010 2011 2012 2013
# Results obtained for periods: 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#                               2015 2016 2017 2018 2019
# -------------------------------------------------------------------------------
#                   Predictors: lnEmployment(2010) lnEmployment(2011)
#                               lnEmployment(2012) lnEmployment(2013)
#                               lnAnnualPay(2010) lnAnnualPay(2011)
#                               lnAnnualPay(2012) lnAnnualPay(2013)
#                               lnUnemploy(2010) lnUnemploy(2011)
#                               lnUnemploy(2012) lnUnemploy(2013) lnPop(2010)
#                               lnPop(2011) lnPop(2012) lnPop(2013)
# -------------------------------------------------------------------------------
# Unless period is specified
# predictors are averaged over: 2005 2006 2007 2008 2009 2010 2011 2012 2013
# -------------------------------------------------------------------------------
#
# Second Step: Run Optimization
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Optimization done
# -------------------------------------------------------------------------------
#
# Third Step: Obtain Results
# -------------------------------------------------------------------------------
# Loss: Root Mean Squared Prediction Error
#
# ---------------------
#    RMSPE |  .0746153
# ---------------------
# -------------------------------------------------------------------------------
# Unit Weights:
#
# -----------------------
#     Co_No | Unit_Weight
# ----------+------------
#        AL |           0
#        AZ |           0
#        AR |           0
#        CA |        .293
#        CO |           0
#        CT |          .5
#        FL |           0
#        GA |           0
#        IL |           0
#        IN |           0
#        KS |        .207
#        KY |           0
#        MD |           0
#        MA |           0
#        MI |           0
#        MS |           0
#        MO |           0
#        NH |           0
#        NJ |           0
#        NM |           0
#        NY |           0
#        NC |           0
#        OH |           0
#        OK |           0
#        OR |           0
#        PA |           0
#        SC |           0
#        TN |           0
#        TX |           0
#        UT |           0
#        VA |           0
#        WV |           0
#        WI |           0
# -----------------------
# -------------------------------------------------------------------------------
# Predictor Balance:
#
# ------------------------------------------------------
#                                |   Treated  Synthetic
# -------------------------------+----------------------
#             lnEmployment(2010) |  11.29926   10.57899
#             lnEmployment(2011) |  11.36879   10.58626
#             lnEmployment(2012) |  11.45343   10.58097
#             lnEmployment(2013) |  11.47223   10.55639
#              lnAnnualPay(2010) |  11.42438   11.37023
#              lnAnnualPay(2011) |  11.48468    11.4226
#              lnAnnualPay(2012) |  11.47924   11.43389
#              lnAnnualPay(2013) |  11.51398    11.4739
#               lnUnemploy(2010) |  2.208274   2.273723
#               lnUnemploy(2011) |  2.140066   2.208492
#               lnUnemploy(2012) |   2.04122   2.113345
#               lnUnemploy(2013) |   1.88707   2.028723
#                    lnPop(2010) |  15.72399   15.73098
#                    lnPop(2011) |  15.73634   15.73555
#                    lnPop(2012) |  15.74661   15.73998
#                    lnPop(2013) |  15.75626   15.74299
# ------------------------------------------------------
# -------------------------------------------------------------------------------
#
# .

# %%
# %%stata
# /* Rename Graph */
# graph rename Graph synthWaAnnualPay, replace
#
# /*  Show the graph from the command above */
# graph display
# Out:
# . /* Rename Graph */
# . graph rename Graph synthWaAnnualPay, replace
# (note: graph synthWaAnnualPay not found)
#
# .
# . /*  Show the graph from the command above */
# . graph display
#
# .

# %% [markdown]
# ### Combine Synthetic WA plots

# %%
# %%stata
# /* For Display */
# graph combine synthWaEmployment synthWaAnnualPay, ///
#     rows(2) cols(1)
#
# /* For File */
# graph export "$graphs/synthWa.png", replace
# Out:
# . /* For Display */
# . graph combine synthWaEmployment synthWaAnnualPay, ///
# >     rows(2) cols(1)
#
# .
# . /* For File */
# . graph export "$graphs/synthWa.png", replace
# file Output/Graphs/synthWa.png written in PNG format
#
# .

# %%
# %%capture
# %%stata
clear
log close
