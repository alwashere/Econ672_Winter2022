# %% [markdown]
# # Data Analysis: Difference-in-Differences
# Data analysis for ECON672 Project

# %%
# %%capture
# Capture suppresses output to screen
import stata_setup
stata_setup.config("/Applications/Stata 17", "be")

# %%
# %%stata
# /* Define paths for data and output */
# global data "Data"
# global output "Output"
# global graphs "$output/Graphs"
# global tables "$output/Tables"
#
# global processed "$data/Processed"
#
# global finalSynthData "$processed/finalSynth.dta"
# Out:
# . /* Define paths for data and output */
# . global data "Data"
#
# . global output "Output"
#
# . global graphs "$output/Graphs"
#
# . global tables "$output/Tables"
#
# .
# . global processed "$data/Processed"
#
# .
# . global finalSynthData "$processed/finalSynth.dta"
#
# .

# %%
# %%capture
# %%stata
log using "$output/analysisDid.log", replace

# %% [markdown]
# ## Load the data

# %%
# %%stata
# use "$finalSynthData", clear
# describe
# Out:
# . use "$finalSynthData", clear
#
# . describe
#
# Contains data from Data/Processed/finalSynth.dta
#  Observations:           646
#     Variables:            24                  5 Feb 2022 19:04
# -------------------------------------------------------------------------------
# Variable      Storage   Display    Value
#     name         type    format    label      Variable label
# -------------------------------------------------------------------------------
# year            float   %10.0g                Year
# employment      long    %10.0g                Annual Reported Employment (NAICS
#                                                 3364)
# state           str2    %9s
# annualPay       long    %10.0g                Average Annual Pay (USD) (NAICS
#                                                 3364)
# lnEmployment    float   %9.0g
# lnAnnualPay     float   %9.0g
# unemploy        double  %10.0g                Annual state level unemployment
#                                                 rate (not seasonaly adjusted)
# lnUnemploy      float   %9.0g                 ln(unemploy)
# pop             long    %10.0g                US Census Population Estimate
# lnPop           float   %9.0g
# fips            byte    %10.0g                fips State Code
# postIncentive   float   %9.0g                 =1 if year >=2014
# t_0             float   %9.0g
# t_lag4          float   %9.0g
# t_lag3          float   %9.0g
# t_lag2          float   %9.0g
# t_lag1          float   %9.0g
# t_lag0          float   %9.0g
# t_lead1         float   %9.0g
# t_lead2         float   %9.0g
# t_lead3         float   %9.0g
# t_lead4         float   %9.0g
# wa              float   %9.0g                 =1 if the state is WA
# treated         float   %9.0g                 =1 if after 2014 and in WA
# -------------------------------------------------------------------------------
# Sorted by: fips  year
#
# .

# %%
# %%stata
# global covariates "lnPop unemploy"
# global waMo "(state=="WA" | state=="MO")"
# global waCa "(state=="WA" | state=="CA")"
# Out:
# . global covariates "lnPop unemploy"
#
# . global waMo "(state=="WA" | state=="MO")"
#
# . global waCa "(state=="WA" | state=="CA")"
#
# .

# %% [markdown]
# ## Descriptive Statistics

# %%
# %%stata
# sort state year
# summarize annualPay employment pop if $waMo
# Out:
# . sort state year
#
# . summarize annualPay employment pop if $waMo
#
#     Variable |        Obs        Mean    Std. dev.       Min        Max
# -------------+---------------------------------------------------------
#    annualPay |         38    94311.68    15963.63      63203     119650
#   employment |         38    48908.84    34760.55      12552      96012
#          pop |         38     6341492    554954.5    5641142    7614893
#
# .

# %% [markdown]
# ## Check Parallel Trends

# %%
# %%stata
# global leads "t_lead4 t_lead3 t_lead2 t_lead1"
# global lags "t_lag1 t_lag2 t_lag3 t_lag4"
# Out:
# . global leads "t_lead4 t_lead3 t_lead2 t_lead1"
#
# . global lags "t_lag1 t_lag2 t_lag3 t_lag4"
#
# .

# %% [markdown]
# ### Levels

# %% [markdown]
# ### Jobs

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg employment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Job LevelTrends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waMoEmploymentTrends)
# Out:
# . reg employment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
#       Source |       SS           df       MS      Number of obs   =        38
# -------------+----------------------------------   F(21, 16)       =     60.61
#        Model |  4.4152e+10        21  2.1025e+09   Prob > F        =    0.0000
#     Residual |   554979375        16  34686210.9   R-squared       =    0.9876
# -------------+----------------------------------   Adj R-squared   =    0.9713
#        Total |  4.4707e+10        37  1.2083e+09   Root MSE        =    5889.5
#
# ------------------------------------------------------------------------------
#   employment | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |  -5515.473   12204.92    -0.45   0.657    -31388.74    20357.79
#      t_lead3 |   -4833.03   10816.11    -0.45   0.661    -27762.15    18096.09
#      t_lead2 |  -3786.763   9024.039    -0.42   0.680    -22916.87    15343.34
#      t_lead1 |  -3178.161   8150.991    -0.39   0.702    -20457.49    14101.17
#          t_0 |      -6200   7745.471    -0.80   0.435    -22619.67    10219.67
#       t_lag1 |  -9139.739   7694.889    -1.19   0.252    -25452.17    7172.697
#       t_lag2 |  -12833.51   8016.403    -1.60   0.129    -29827.53    4160.502
#       t_lag3 |  -18659.63   8624.665    -2.16   0.046     -36943.1   -376.1569
#       t_lag4 |  -18177.01   9457.759    -1.92   0.073    -38226.56    1872.545
#              |
#         year |
#        2002  |  -5250.519   6354.472    -0.83   0.421     -18721.4    8220.361
#        2003  |  -11292.33   6632.257    -1.70   0.108    -25352.09    2767.423
#        2004  |  -13214.95   6336.926    -2.09   0.053    -26648.63    218.7342
#        2005  |   -13485.9   6081.779    -2.22   0.041    -26378.69   -593.1043
#        2006  |  -12229.93   6232.698    -1.96   0.067    -25442.66    982.7982
#        2007  |   -10543.5   6408.524    -1.65   0.119    -24128.96    3041.962
#        2008  |  -8763.861   6601.947    -1.33   0.203    -22759.36     5231.64
#        2009  |  -4531.181   10801.95    -0.42   0.680     -27430.3    18367.94
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |  -1966.288   5901.534    -0.33   0.743    -14476.98    10544.41
#        2019  |          0  (omitted)
#              |
#         1.wa |   54091.73   5323.506    10.16   0.000      42806.4    65377.06
#        lnPop |   109132.4   39117.33     2.79   0.013     26207.34    192057.4
#     unemploy |  -1783.489   2483.638    -0.72   0.483    -7048.567     3481.59
#        _cons |   -1666825   607087.5    -2.75   0.014     -2953793     -379857
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Job LevelTrends: WA-MO) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waMoEmploymentTrends)
#
# .

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg employment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Job Level Trends: WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waCaEmploymentTrends)
# Out:
# . reg employment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
#       Source |       SS           df       MS      Number of obs   =        38
# -------------+----------------------------------   F(21, 16)       =      6.32
#        Model |  2.5524e+09        21   121543802   Prob > F        =    0.0002
#     Residual |   307602777        16  19225173.6   R-squared       =    0.8924
# -------------+----------------------------------   Adj R-squared   =    0.7513
#        Total |  2.8600e+09        37  77297908.4   Root MSE        =    4384.7
#
# ------------------------------------------------------------------------------
#   employment | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |  -6776.389   8681.027    -0.78   0.446    -25179.35    11626.57
#      t_lead3 |  -7046.695   8571.392    -0.82   0.423    -25217.23    11123.84
#      t_lead2 |  -10111.69     8192.5    -1.23   0.235    -27479.01    7255.637
#      t_lead1 |  -15933.33    7871.17    -2.02   0.060    -32619.46    752.8099
#          t_0 |  -23841.99   7912.864    -3.01   0.008    -40616.51   -7067.467
#       t_lag1 |  -27389.69   8172.591    -3.35   0.004    -44714.81   -10064.57
#       t_lag2 |  -34376.35   8588.884    -4.00   0.001    -52583.97   -16168.73
#       t_lag3 |  -42206.47   8993.598    -4.69   0.000    -61272.04   -23140.89
#       t_lag4 |  -43316.94   9581.672    -4.52   0.000    -63629.18    -23004.7
#              |
#         year |
#        2002  |  -5317.245   4611.955    -1.15   0.266    -15094.15    4459.663
#        2003  |  -15101.06   4733.276    -3.19   0.006    -25135.15   -5066.958
#        2004  |  -22153.19   4670.628    -4.74   0.000    -32054.48    -12251.9
#        2005  |  -25414.13   4766.389    -5.33   0.000    -35518.42   -15309.83
#        2006  |  -26127.39   5017.012    -5.21   0.000    -36762.98    -15491.8
#        2007  |  -24859.73   5247.964    -4.74   0.000    -35984.92   -13734.54
#        2008  |  -19346.78   5668.074    -3.41   0.004    -31362.57   -7331.004
#        2009  |   -6760.32   7756.395    -0.87   0.396    -23203.14    9682.503
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |  -1392.818   4397.891    -0.32   0.756    -10715.93    7930.295
#        2019  |          0  (omitted)
#              |
#         1.wa |   306938.1   78475.85     3.91   0.001     140576.7    473299.5
#        lnPop |   176991.6   45750.38     3.87   0.001      80005.1      273978
#     unemploy |  -4393.014   1047.014    -4.20   0.001    -6612.586   -2173.443
#        _cons |   -2958951   794199.8    -3.73   0.002     -4642579    -1275322
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Job Level Trends: WA-CA) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waCaEmploymentTrends)
#
# .

# %% [markdown]
# ### Annual Pay Level

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg annualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo, robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annual Pay Level Trends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waMoAnnualPayTrends)
# Out:
# . reg annualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo, robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(21, 16)         =    1569.63
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9939
#                                                 Root MSE          =     1892.7
#
# ------------------------------------------------------------------------------
#              |               Robust
#    annualPay | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |   25703.88   2977.787     8.63   0.000     19391.26    32016.51
#      t_lead3 |   31597.74   2577.402    12.26   0.000     26133.89    37061.59
#      t_lead2 |   34677.05   3743.971     9.26   0.000     26740.18    42613.91
#      t_lead1 |   37808.61   2964.735    12.75   0.000     31523.65    44093.57
#          t_0 |   46011.68   1784.481    25.78   0.000     42228.75    49794.61
#       t_lag1 |   43742.87   1988.144    22.00   0.000     39528.19    47957.54
#       t_lag2 |   44538.44   2080.235    21.41   0.000     40128.53    48948.34
#       t_lag3 |   50406.55   2386.933    21.12   0.000     45346.48    55466.62
#       t_lag4 |   53794.48   3333.554    16.14   0.000     46727.66     60861.3
#              |
#         year |
#        2002  |   6371.931   1356.354     4.70   0.000     3496.588    9247.274
#        2003  |   11075.61   2830.227     3.91   0.001     5075.795    17075.42
#        2004  |   12595.23    1544.05     8.16   0.000     9321.989    15868.47
#        2005  |   18451.29   2169.775     8.50   0.000     13851.57    23051.01
#        2006  |   26329.64   1279.238    20.58   0.000     23617.78     29041.5
#        2007  |   22421.45   1574.238    14.24   0.000     19084.22    25758.69
#        2008  |    23694.2    1450.25    16.34   0.000     20619.81    26768.59
#        2009  |    22034.8   2674.171     8.24   0.000     16365.81    27703.79
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |   1458.558   2143.636     0.68   0.506    -3085.747    6002.862
#        2019  |          0  (omitted)
#              |
#         1.wa |  -654.0677   1600.638    -0.41   0.688    -4047.268    2739.132
#        lnPop |   174.8345   12269.71     0.01   0.989     -25835.8    26185.46
#     unemploy |   412.1904   693.8248     0.59   0.561    -1058.652    1883.033
#        _cons |   59622.45   189473.8     0.31   0.757    -342044.1      461289
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Annual Pay Level Trends: WA-MO) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waMoAnnualPayTrends)
#
# .

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg annualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annual Pay Level Trends WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waCaAnnualPayTrends)
# Out:
# . reg annualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
#       Source |       SS           df       MS      Number of obs   =        38
# -------------+----------------------------------   F(21, 16)       =    143.97
#        Model |  8.2350e+09        21   392141425   Prob > F        =    0.0000
#     Residual |  43579579.3        16   2723723.7   R-squared       =    0.9947
# -------------+----------------------------------   Adj R-squared   =    0.9878
#        Total |  8.2785e+09        37   223744581   Root MSE        =    1650.4
#
# ------------------------------------------------------------------------------
#    annualPay | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |   11864.08   3267.514     3.63   0.002     4937.261     18790.9
#      t_lead3 |   17760.28   3226.248     5.50   0.000     10920.93    24599.62
#      t_lead2 |   18704.64   3083.634     6.07   0.000     12167.63    25241.66
#      t_lead1 |   22039.35   2962.686     7.44   0.000     15758.73    28319.96
#          t_0 |   29244.86    2978.38     9.82   0.000     22930.98    35558.75
#       t_lag1 |   29146.09    3076.14     9.47   0.000     22624.97    35667.22
#       t_lag2 |   28779.02   3232.832     8.90   0.000     21925.73    35632.32
#       t_lag3 |   35549.13   3385.165    10.50   0.000      28372.9    42725.36
#       t_lag4 |   39638.96   3606.515    10.99   0.000     31993.49    47284.43
#              |
#         year |
#        2002  |   2810.921   1735.927     1.62   0.125    -869.0802    6490.922
#        2003  |   4884.025   1781.592     2.74   0.014     1107.219    8660.831
#        2004  |   9505.736   1758.011     5.41   0.000     5778.919    13232.55
#        2005  |   13878.69   1794.056     7.74   0.000     10075.46    17681.92
#        2006  |   20446.48   1888.389    10.83   0.000     16443.27    24449.68
#        2007  |   18266.54   1975.319     9.25   0.000     14079.05    22454.03
#        2008  |   16936.78   2133.447     7.94   0.000     12414.07    21459.48
#        2009  |   11807.93   2919.485     4.04   0.001     5618.893    17996.96
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |    421.826   1655.354     0.25   0.802    -3087.368    3931.019
#        2019  |          0  (omitted)
#              |
#         1.wa |   126034.2   29538.09     4.27   0.001      63416.2    188652.1
#        lnPop |      70689   17220.32     4.10   0.001     34183.56    107194.4
#     unemploy |   1559.949   394.0933     3.96   0.001     724.5085    2395.389
#        _cons |   -1172436   298934.6    -3.92   0.001     -1806149   -538723.4
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Annual Pay Level Trends WA-CA) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waCaAnnualPayTrends)
#
# .

# %% [markdown]
# ### Combine WA/MO Employment and Pay Level Trends

# %%
# %%stata
# /* Output combined WA-MO Trends */
# /* Display*/
# graph combine waMoEmploymentTrends waMoAnnualPayTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waMoLvlTrends.png", replace
# Out:
# . /* Output combined WA-MO Trends */
# . /* Display*/
# . graph combine waMoEmploymentTrends waMoAnnualPayTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waMoLvlTrends.png", replace
# file Output/Graphs/waMoLvlTrends.png written in PNG format
#
# .

# %%
# %%stata
# /* Output combined WA-CA Trends */
# /* Display*/
# graph combine waCaEmploymentTrends waCaAnnualPayTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waCaLvlTrends.png", replace
# Out:
# . /* Output combined WA-CA Trends */
# . /* Display*/
# . graph combine waCaEmploymentTrends waCaAnnualPayTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waCaLvlTrends.png", replace
# file Output/Graphs/waCaLvlTrends.png written in PNG format
#
# .

# %% [markdown]
# ### Job Growth

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg lnEmployment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Job Growth Trends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waMoEmploymentLnTrends)
# Out:
# . reg lnEmployment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
#       Source |       SS           df       MS      Number of obs   =        38
# -------------+----------------------------------   F(21, 16)       =    155.86
#        Model |  27.0425222        21  1.28773915   Prob > F        =    0.0000
#     Residual |  .132194393        16   .00826215   R-squared       =    0.9951
# -------------+----------------------------------   Adj R-squared   =    0.9888
#        Total |  27.1747166        37  .734451799   Root MSE        =     .0909
#
# ------------------------------------------------------------------------------
# lnEmployment | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |  -.0431854   .1549023    -0.28   0.784    -.3715636    .2851928
#      t_lead3 |  -.0185779    .143894    -0.13   0.899    -.3236195    .2864637
#      t_lead2 |   .0099801   .1282277     0.08   0.939    -.2618505    .2818107
#      t_lead1 |   .1237009   .1203194     1.03   0.319    -.1313649    .3787667
#          t_0 |   .1101432   .1171532     0.94   0.361    -.1382104    .3584968
#       t_lag1 |   .0747706   .1191866     0.63   0.539    -.1778936    .3274348
#       t_lag2 |   .0307005   .1260449     0.24   0.811    -.2365027    .2979037
#       t_lag3 |  -.0223771   .1404355    -0.16   0.875    -.3200871     .275333
#       t_lag4 |   .0431798   .1600346     0.27   0.791    -.2960783    .3824379
#              |
#         year |
#        2002  |   -.088089   .0971468    -0.91   0.378    -.2940309    .1178529
#        2003  |  -.2026425   .1006956    -2.01   0.061    -.4161077    .0108226
#        2004  |  -.1198513   .0972377    -1.23   0.236    -.3259861    .0862835
#        2005  |  -.1066449   .0937349    -1.14   0.272    -.3053541    .0920643
#        2006  |  -.0641479   .0966837    -0.66   0.516    -.2691082    .1408124
#        2007  |  -.0492173    .099877    -0.49   0.629    -.2609471    .1625124
#        2008  |  -.0336611   .1010383    -0.33   0.743    -.2478528    .1805306
#        2009  |  -.0187194   .1428345    -0.13   0.897    -.3215151    .2840763
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |  -.0615329   .0911333    -0.68   0.509     -.254727    .1316611
#        2019  |          0  (omitted)
#              |
#         1.wa |    1.62645   .0810412    20.07   0.000     1.454651     1.79825
#        lnPop |   .4130244   .6113018     0.68   0.509    -.8828775    1.708926
#   lnUnemploy |  -.0165018   .2091446    -0.08   0.938    -.4598687     .426865
#        _cons |   3.242574   9.436135     0.34   0.736    -16.76114    23.24629
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Job Growth Trends: WA-MO) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waMoEmploymentLnTrends)
#
# .

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg lnEmployment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Job Growth Trends: WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waCaEmploymentLnTrends)
# Out:
# . reg lnEmployment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
#       Source |       SS           df       MS      Number of obs   =        38
# -------------+----------------------------------   F(21, 16)       =      8.14
#        Model |    .4179818        21  .019903895   Prob > F        =    0.0000
#     Residual |  .039112662        16  .002444541   R-squared       =    0.9144
# -------------+----------------------------------   Adj R-squared   =    0.8021
#        Total |  .457094462        37  .012353904   Root MSE        =    .04944
#
# ------------------------------------------------------------------------------
# lnEmployment | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |  -.0159428   .1034187    -0.15   0.879    -.2351806    .2032949
#      t_lead3 |  -.0165674   .1026038    -0.16   0.874    -.2340777    .2009429
#      t_lead2 |  -.0608183   .0983745    -0.62   0.545    -.2693629    .1477263
#      t_lead1 |  -.1463239   .0930842    -1.57   0.136    -.3436536    .0510059
#          t_0 |  -.2615562   .0915919    -2.86   0.011    -.4557223   -.0673901
#       t_lag1 |   -.327766   .0928963    -3.53   0.003    -.5246973   -.1308347
#       t_lag2 |  -.4322106   .0969958    -4.46   0.000    -.6378325   -.2265887
#       t_lag3 |  -.5598335   .1014218    -5.52   0.000    -.7748381   -.3448288
#       t_lag4 |  -.6108443   .1088501    -5.61   0.000    -.8415962   -.3800923
#              |
#         year |
#        2002  |  -.0251047   .0540699    -0.46   0.649    -.1397278    .0895185
#        2003  |  -.1551014   .0558418    -2.78   0.013    -.2734808    -.036722
#        2004  |  -.2699465   .0533997    -5.06   0.000    -.3831488   -.1567442
#        2005  |  -.3318819   .0537452    -6.18   0.000    -.4458166   -.2179472
#        2006  |  -.3595732   .0571975    -6.29   0.000    -.4808266   -.2383199
#        2007  |   -.342497   .0597059    -5.74   0.000    -.4690679    -.215926
#        2008  |  -.2222501    .064651    -3.44   0.003     -.359304   -.0851962
#        2009  |  -.0137443   .0934635    -0.15   0.885    -.2118781    .1843895
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |  -.0019327   .0497367    -0.04   0.969    -.1073698    .1035045
#        2019  |          0  (omitted)
#              |
#         1.wa |   3.637419   .8939218     4.07   0.001     1.742389    5.532448
#        lnPop |    2.10454   .5207158     4.04   0.001     1.000672    3.208408
#   lnUnemploy |  -.5463079   .1047027    -5.22   0.000    -.7682677   -.3243481
#        _cons |  -24.18351   9.068436    -2.67   0.017    -43.40774   -4.959288
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Job Growth Trends: WA-CA) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waCaEmploymentLnTrends)
#
# .

# %% [markdown]
# ### Wage growth

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg lnAnnualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo, robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annaul Pay Growth Trends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waMoAnnualPayLnTrends)
# Out:
# . reg lnAnnualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo, robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(20, 16)         =          .
#                                                 Prob > F          =          .
#                                                 R-squared         =     0.9941
#                                                 Root MSE          =     .02039
#
# ------------------------------------------------------------------------------
#              |               Robust
#  lnAnnualPay | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |   .3347416   .0244231    13.71   0.000      .282967    .3865162
#      t_lead3 |    .397764   .0220602    18.03   0.000     .3509985    .4445295
#      t_lead2 |   .4300073   .0360577    11.93   0.000     .3535684    .5064462
#      t_lead1 |   .4627688   .0278405    16.62   0.000     .4037496    .5217881
#          t_0 |   .5421518   .0189351    28.63   0.000     .5020113    .5822923
#       t_lag1 |    .524667   .0226114    23.20   0.000     .4767331     .572601
#       t_lag2 |   .5343606   .0254678    20.98   0.000     .4803713    .5883499
#       t_lag3 |   .5911902   .0312223    18.93   0.000     .5250019    .6573784
#       t_lag4 |   .6245847   .0408785    15.28   0.000     .5379262    .7112432
#              |
#         year |
#        2002  |    .093687   .0150543     6.22   0.000     .0617734    .1256007
#        2003  |    .157301   .0385123     4.08   0.001     .0756586    .2389434
#        2004  |   .1781946   .0173605    10.26   0.000      .141392    .2149972
#        2005  |   .2530212   .0248159    10.20   0.000     .2004139    .3056285
#        2006  |   .3465832   .0154501    22.43   0.000     .3138305     .379336
#        2007  |   .3032774    .019315    15.70   0.000     .2623314    .3442235
#        2008  |   .3156199   .0158719    19.89   0.000      .281973    .3492668
#        2009  |   .2934923   .0236145    12.43   0.000     .2434318    .3435528
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |   .0116335   .0175038     0.66   0.516    -.0254728    .0487399
#        2019  |          0  (omitted)
#              |
#         1.wa |  -.0027417   .0195616    -0.14   0.890    -.0442104    .0387271
#        lnPop |  -.0401183   .1449592    -0.28   0.786    -.3474181    .2671815
#   lnUnemploy |   .0418947   .0441644     0.95   0.357    -.0517295     .135519
#        _cons |   11.62655   2.203701     5.28   0.000     6.954916    16.29819
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Annaul Pay Growth Trends: WA-MO) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waMoAnnualPayLnTrends)
#
# .

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg lnAnnualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annual Pay Growth Trends WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     name(waCaAnnualPayLnTrends)
# Out:
# . reg lnAnnualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
#       Source |       SS           df       MS      Number of obs   =        38
# -------------+----------------------------------   F(21, 16)       =    147.39
#        Model |  1.02760718        21  .048933675   Prob > F        =    0.0000
#     Residual |  .005312032        16  .000332002   R-squared       =    0.9949
# -------------+----------------------------------   Adj R-squared   =    0.9881
#        Total |  1.03291921        37  .027916735   Root MSE        =    .01822
#
# ------------------------------------------------------------------------------
#  lnAnnualPay | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      t_lead4 |   .2077776   .0381128     5.45   0.000     .1269821    .2885731
#      t_lead3 |   .2705808   .0378125     7.16   0.000     .1904219    .3507396
#      t_lead2 |   .2795423   .0362539     7.71   0.000     .2026875     .356397
#      t_lead1 |   .3153684   .0343042     9.19   0.000     .2426467    .3880901
#          t_0 |    .389714   .0337543    11.55   0.000     .3181582    .4612699
#       t_lag1 |    .396415    .034235    11.58   0.000     .3238401    .4689899
#       t_lag2 |   .3983592   .0357458    11.14   0.000     .3225815    .4741368
#       t_lag3 |   .4711678   .0373769    12.61   0.000     .3919323    .5504032
#       t_lag4 |   .5176423   .0401144    12.90   0.000     .4326035    .6026811
#              |
#         year |
#        2002  |   .0491292   .0199263     2.47   0.025     .0068873    .0913712
#        2003  |   .0828128   .0205793     4.02   0.001     .0391866    .1264391
#        2004  |   .1483596   .0196793     7.54   0.000     .1066413    .1900779
#        2005  |   .2090216   .0198067    10.55   0.000     .1670334    .2510099
#        2006  |   .2948959   .0210789    13.99   0.000     .2502105    .3395813
#        2007  |   .2732359   .0220034    12.42   0.000     .2265908     .319881
#        2008  |   .2544092   .0238258    10.68   0.000     .2039009    .3049176
#        2009  |   .2010326    .034444     5.84   0.000     .1280145    .2740507
#        2010  |          0  (omitted)
#        2011  |          0  (omitted)
#        2012  |          0  (omitted)
#        2013  |          0  (omitted)
#        2014  |          0  (omitted)
#        2015  |          0  (omitted)
#        2016  |          0  (omitted)
#        2017  |          0  (omitted)
#        2018  |  -.0005847   .0183294    -0.03   0.975    -.0394413    .0382719
#        2019  |          0  (omitted)
#              |
#         1.wa |   .9954978   .3294361     3.02   0.008     .2971245    1.693871
#        lnPop |   .5513459   .1918989     2.87   0.011     .1445385    .9581533
#   lnUnemploy |   .1363955    .038586     3.53   0.003     .0545968    .2181941
#        _cons |   1.252275   3.341981     0.37   0.713    -5.832409    8.336959
# ------------------------------------------------------------------------------
#
# .
# . coefplot , keep($leads t_0 $lags ) ///
# >     vertical title(Annual Pay Growth Trends WA-CA) ///
# >     yline(0) ///
# >     addplot(line @b @at,lpattern(dash)) ///
# >     name(waCaAnnualPayLnTrends)
#
# .

# %% [markdown]
# ### Combine WA/MO Employment and Pay Trends

# %%
# %%stata
# /* Output combined WA-MO Trends */
# /* Display*/
# graph combine waMoEmploymentTrends waMoAnnualPayTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waMoLnTrends.png", replace
# Out:
# . /* Output combined WA-MO Trends */
# . /* Display*/
# . graph combine waMoEmploymentTrends waMoAnnualPayTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waMoLnTrends.png", replace
# file Output/Graphs/waMoLnTrends.png written in PNG format
#
# .

# %%
# %%stata
# /* Output combined WA-CA Trends */
# /* Display*/
# graph combine waCaEmploymentTrends waCaAnnualPayTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waCaLnTrends.png", replace
# Out:
# . /* Output combined WA-CA Trends */
# . /* Display*/
# . graph combine waCaEmploymentTrends waCaAnnualPayTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waCaLnTrends.png", replace
# file Output/Graphs/waCaLnTrends.png written in PNG format
#
# .

# %% [markdown]
# ## Basic Model

# %%
# %%stata
# // Job Growth DID Model
# reg lnEmployment ///
#     i.wa postIncentive treated ///
#     if $waMo, robust
#
# eststo employmentRegBasic
#
# reg lnEmployment ///
#     i.wa postIncentive treated ///
#     $covariates if $waMo, robust
#
# eststo employmentRegCovariates
#
#
# // Wages DID Model
# reg lnAnnualPay ///
#     i.wa postIncentive treated ///
#     if $waMo, robust
#
# eststo wagesRegBasic
#
# reg lnAnnualPay ///
#     i.wa postIncentive treated ///
#     $covariates if $waMo, robust
#
# eststo wagesRegCovariates
# Out:
# . // Job Growth DID Model
# . reg lnEmployment ///
# >     i.wa postIncentive treated ///
# >     if $waMo, robust
#
# Linear regression                               Number of obs     =         38
#                                                 F(3, 34)          =    1824.33
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9875
#                                                 Root MSE          =     .09988
#
# ------------------------------------------------------------------------------
#              |               Robust
# lnEmployment | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         1.wa |   1.676524   .0456306    36.74   0.000     1.583792    1.769257
# postIncent~e |   .1231911   .0297135     4.15   0.000     .0628061    .1835761
#      treated |    .000811   .0532653     0.02   0.988     -.107437     .109059
#        _cons |   9.596493   .0230175   416.92   0.000     9.549715     9.64327
# ------------------------------------------------------------------------------
#
# .
# . eststo employmentRegBasic
#
# .
# . reg lnEmployment ///
# >     i.wa postIncentive treated ///
# >     $covariates if $waMo, robust
#
# Linear regression                               Number of obs     =         38
#                                                 F(5, 32)          =    1009.64
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9910
#                                                 Root MSE          =     .08752
#
# ------------------------------------------------------------------------------
#              |               Robust
# lnEmployment | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         1.wa |   1.542465   .0834626    18.48   0.000     1.372458    1.712473
# postIncent~e |   .0866095   .0461634     1.88   0.070    -.0074223    .1806413
#      treated |   -.125827    .062044    -2.03   0.051    -.2522065    .0005525
#        lnPop |   1.368275    .610373     2.24   0.032     .1249862    2.611564
#   lnUnemploy |   .0420593   .0470511     0.89   0.378    -.0537808    .1378994
#        _cons |  -11.80449   9.478336    -1.25   0.222    -31.11123    7.502253
# ------------------------------------------------------------------------------
#
# .
# . eststo employmentRegCovariates
#
# .
# .
# . // Wages DID Model
# . reg lnAnnualPay ///
# >     i.wa postIncentive treated ///
# >     if $waMo, robust
#
# Linear regression                               Number of obs     =         38
#                                                 F(3, 34)          =      30.97
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.5814
#                                                 Root MSE          =     .11818
#
# ------------------------------------------------------------------------------
#              |               Robust
#  lnAnnualPay | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         1.wa |  -.0070087   .0550182    -0.13   0.899    -.1188191    .1048017
# postIncent~e |    .279508   .0432351     6.46   0.000     .1916436    .3673723
#      treated |    .007682   .0596677     0.13   0.898    -.1135773    .1289413
#        _cons |   11.35382   .0410953   276.28   0.000     11.27031    11.43734
# ------------------------------------------------------------------------------
#
# .
# . eststo wagesRegBasic
#
# .
# . reg lnAnnualPay ///
# >     i.wa postIncentive treated ///
# >     $covariates if $waMo, robust
#
# Linear regression                               Number of obs     =         38
#                                                 F(5, 32)          =     102.99
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.8836
#                                                 Root MSE          =     .06423
#
# ------------------------------------------------------------------------------
#              |               Robust
#  lnAnnualPay | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         1.wa |  -.2733115   .0373775    -7.31   0.000     -.349447    -.197176
# postIncent~e |   .1832677   .0383859     4.77   0.000     .1050783    .2614572
#      treated |   -.240254   .0487679    -4.93   0.000    -.3395909    -.140917
#        lnPop |   2.743283   .2764681     9.92   0.000     2.180135     3.30643
#   lnUnemploy |   .0267103   .0508375     0.53   0.603    -.0768423     .130263
#        _cons |  -31.44747   4.336318    -7.25   0.000    -40.28026   -22.61468
# ------------------------------------------------------------------------------
#
# .
# . eststo wagesRegCovariates
#
# .

# %%
# %%stata
# /* Results */
# esttab employmentRegBasic employmentRegCovariates ///
#     wagesRegBasic wagesRegCovariates, ///
#     noconstant se ar2 obslast scalars(F) ///
#     keep(1.wa treated lnPop lnUnemploy)  ///
#     order(treated 1.wa lnPop) ///
#     coeflabels(treated "DID ATT" ///
#                1.wa "Washington State" ///
#                lnPop "ln(population)" ///
#                lnUnemploy "ln(Unemployment Rate)")
# Out:
# . /* Results */
# . esttab employmentRegBasic employmentRegCovariates ///
# >     wagesRegBasic wagesRegCovariates, ///
# >     noconstant se ar2 obslast scalars(F) ///
# >     keep(1.wa treated lnPop lnUnemploy)  ///
# >     order(treated 1.wa lnPop) ///
# >     coeflabels(treated "DID ATT" ///
# >                1.wa "Washington State" ///
# >                lnPop "ln(population)" ///
# >                lnUnemploy "ln(Unemployment Rate)")
#
# ----------------------------------------------------------------------------
#                       (1)             (2)             (3)             (4)
#              lnEmployment    lnEmployment     lnAnnualPay     lnAnnualPay
# ----------------------------------------------------------------------------
# DID ATT          0.000811          -0.126         0.00768          -0.240***
#                  (0.0533)        (0.0620)        (0.0597)        (0.0488)
#
# Washington~e        1.677***        1.542***     -0.00701          -0.273***
#                  (0.0456)        (0.0835)        (0.0550)        (0.0374)
#
# ln(populat~)                        1.368*                          2.743***
#                                   (0.610)                         (0.276)
#
# ln(Unemplo~)                       0.0421                          0.0267
#                                  (0.0471)                        (0.0508)
# ----------------------------------------------------------------------------
# adj. R-sq           0.986           0.990           0.544           0.865
# F                  1824.3          1009.6           30.97           103.0
# N                      38              38              38              38
# ----------------------------------------------------------------------------
# Standard errors in parentheses
# * p<0.05, ** p<0.01, *** p<0.001
#
# .

# %%
# %%stata
# /* Results */
# esttab employmentRegBasic employmentRegCovariates ///
#     wagesRegBasic wagesRegCovariates ///
#     using $tables/regTable.tex, replace ///
#     noconstant se ar2 obslast scalars(F) ///
#     keep(1.wa treated lnPop)  ///
#     order(treated 1.wa lnPop) ///
#     mtitles("ln(employment)" "(1)+X" "ln(wages)" "(3)+X") ///
#     coeflabels(treated "DID ATT" ///
#                1.wa "Washington State" ///
#                lnPop "ln(population)")
# Out:
# . /* Results */
# . esttab employmentRegBasic employmentRegCovariates ///
# >     wagesRegBasic wagesRegCovariates ///
# >     using $tables/regTable.tex, replace ///
# >     noconstant se ar2 obslast scalars(F) ///
# >     keep(1.wa treated lnPop)  ///
# >     order(treated 1.wa lnPop) ///
# >     mtitles("ln(employment)" "(1)+X" "ln(wages)" "(3)+X") ///
# >     coeflabels(treated "DID ATT" ///
# >                1.wa "Washington State" ///
# >                lnPop "ln(population)")
# (output written to Output/Tables/regTable.tex)
#
# .

# %%
# %%capture
# %%stata
clear
log close

# %%
# %%stata
# graph drop *
