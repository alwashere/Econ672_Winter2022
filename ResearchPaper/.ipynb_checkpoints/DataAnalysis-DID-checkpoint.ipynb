# %% [markdown]
# # Data Analysis: Difference-in-Differences
# Data analysis for ECON672 Project

# %%
# %%capture
# Capture suppresses output to screen
import stata_setup
stata_setup.config("/Applications/Stata 17", "be")

# %%
# %%stata
# /* Define paths for data and output */
# global data "Data"
# global output "Output"
# global graphs "$output/Graphs"
# global tables "$output/Tables"
#
# global processed "$data/Processed"
#
# global finalSynthData "$processed/finalSynth.dta"
# Out:
# . /* Define paths for data and output */
# . global data "Data"
#
# . global output "Output"
#
# . global graphs "$output/Graphs"
#
# . global tables "$output/Tables"
#
# .
# . global processed "$data/Processed"
#
# .
# . global finalSynthData "$processed/finalSynth.dta"
#
# .

# %%
# %%capture
# %%stata
log using "$output/analysisDid.log", replace

# %% [markdown]
# ## Load the data

# %%
# %%stata
# use "$finalSynthData", clear
# describe
# Out:
# . use "$finalSynthData", clear
#
# . describe
#
# Contains data from Data/Processed/finalSynth.dta
#  Observations:           646
#     Variables:            24                  5 Feb 2022 19:04
# -------------------------------------------------------------------------------
# Variable      Storage   Display    Value
#     name         type    format    label      Variable label
# -------------------------------------------------------------------------------
# year            float   %10.0g                Year
# employment      long    %10.0g                Annual Reported Employment (NAICS
#                                                 3364)
# state           str2    %9s
# annualPay       long    %10.0g                Average Annual Pay (USD) (NAICS
#                                                 3364)
# lnEmployment    float   %9.0g
# lnAnnualPay     float   %9.0g
# unemploy        double  %10.0g                Annual state level unemployment
# ...

# %%
# %%stata
# global covariates "pop unemploy"
# global waMo "(state=="WA" | state=="MO")"
# global waCa "(state=="WA" | state=="CA")"
# Out:
# . global covariates "pop unemploy"
#
# . global waMo "(state=="WA" | state=="MO")"
#
# . global waCa "(state=="WA" | state=="CA")"
#
# .

# %% [markdown]
# ## Descriptive Statistics

# %%
# %%stata
# estpost summarize employment annualPay unemploy pop if state=="WA", quietly
# eststo waSum
#
# estpost summarize employment annualPay unemploy pop if state=="CA", quietly
# eststo caSum
#
# estpost summarize employment annualPay unemploy pop if state=="MO", quietly
# eststo moSum
#
# /* For Display */
# esttab waSum moSum caSum, ///
#     obslast nonumbers ///
#     cells( (mean(fmt(%15.2fc) label("Mean")))  ///
#           (sd(par label("SD"))) )  ///
#     coeflabels(employment "Annual Employment" ///
#               annualPay "Annual Pay" ///
#               unemploy "Annual Unemployment Rate" ///
#               pop "Est Population") ///
#     mtitles("WA (Treated)" "Missouri (Control 1)" "California (Control 1)") ///
#     addnotes("Standard Deviations in paranthesis" "NAICS 3364 for years 2001-2019") ///
#     title(DID Summary Statistics)
#
# /* For Ouput */
# esttab waSum moSum caSum using $tables/waMoCaSum.tex, ///
#     replace ///
#     obslast nonumbers ///
#     cells( (mean(fmt(%15.2fc) label("Mean"))) ///
#           (sd(par label("SD"))) ) ///
#     coeflabels(employment "Annual Employment" ///
#               annualPay "Annual Pay" ///
#               unemploy "Annual Unemployment Rate" ///
#               pop "Est Population") ///
#     mtitles("WA (Treated)" "Missouri (Control 1)" "California (Control 1)") ///
#     addnotes("Standard Deviations in paranthesis" "NAICS 3364 for years 2001-2019")
# Out:
# . estpost summarize employment annualPay unemploy pop if state=="WA", quietly
#
# . eststo waSum
#
# .
# . estpost summarize employment annualPay unemploy pop if state=="CA", quietly
#
# . eststo caSum
#
# .
# . estpost summarize employment annualPay unemploy pop if state=="MO", quietly
#
# . eststo moSum
#
# .
# . /* For Display */
# . esttab waSum moSum caSum, ///
# >     obslast nonumbers ///
# >     cells( (mean(fmt(%15.2fc) label("Mean")))  ///
# >           (sd(par label("SD"))) )  ///
# >     coeflabels(employment "Annual Employment" ///
# >               annualPay "Annual Pay" ///
# >               unemploy "Annual Unemployment Rate" ///
# >               pop "Est Population") ///
# >     mtitles("WA (Treated)" "Missouri (Control 1)" "California (Control 1)") /
# > //
# >     addnotes("Standard Deviations in paranthesis" "NAICS 3364 for years 2001-
# > 2019") ///
# >     title(DID Summary Statistics)
#
# DID Summary Statistics
# ...

# %% [markdown]
# ## Check Parallel Trends

# %%
# %%stata
# global leads "t_lead4 t_lead3 t_lead2 t_lead1"
# global lags "t_lag1 t_lag2 t_lag3 t_lag4"
# Out:
# . global leads "t_lead4 t_lead3 t_lead2 t_lead1"
#
# . global lags "t_lag1 t_lag2 t_lag3 t_lag4"
#
# .

# %%
# %%stata
# global nameLeads "t_lead4=2010 t_lead3=2011 t_lead2=2012 t_lead1=2013"
# global nameLags "t_lag1=2015 t_lag2=2016 t_lag3=2017 t_lag4=2018"
# global plotNames "$nameLeads t_0=2014 $nameLags"
# Out:
# . global nameLeads "t_lead4=2010 t_lead3=2011 t_lead2=2012 t_lead1=2013"
#
# . global nameLags "t_lag1=2015 t_lag2=2016 t_lag3=2017 t_lag4=2018"
#
# . global plotNames "$nameLeads t_0=2014 $nameLags"
#
# .

# %% [markdown]
# ### Levels

# %% [markdown]
# ### Jobs

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg employment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo, ///
#     robust
#
# coefplot , keep($leads t_0 $lags) ///
#     vertical title(Job Level Trends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     format(%9.0gc) ///
#     name(waMoEmploymentLvlTrends)
# Out:
# . reg employment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo, ///
# >     robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(21, 16)         =      92.56
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9875
#                                                 Root MSE          =     5918.3
#
# ...

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg employment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa, ///
#     robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Job Level Trends: WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     ylabel(-10000(20000)40000 0) ///
#     format(%9.0gc) ///
#     name(waCaEmploymentLvlTrends)
# Out:
# . reg employment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa, ///
# >     robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(21, 16)         =      13.84
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9102
#                                                 Root MSE          =     4006.5
#
# ...

# %% [markdown]
# ### Annual Pay Level

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg annualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo, ///
#     robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annual Pay Level Trends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     ylabel(20000(20000)60000 0) ///
#     format(%9.0gc) ///
#     name(waMoAnnualPayLvlTrends)
# Out:
# . reg annualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo, ///
# >     robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(21, 16)         =    1356.29
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9939
#                                                 Root MSE          =     1892.5
#
# ...

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg annualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa, ///
#     robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annual Pay Level Trends WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     ylabel(20000(20000)60000 0) ///
#     format(%9.0gc) ///
#     name(waCaAnnualPayLvlTrends)
# Out:
# . reg annualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa, ///
# >     robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(21, 16)         =    6755.72
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9963
#                                                 Root MSE          =     1374.8
#
# ...

# %% [markdown]
# ### Combine WA/MO Employment and Pay Level Trends

# %%
# %%stata
# /* Output combined WA-MO Trends */
# /* Display*/
# graph combine waMoEmploymentLvlTrends waMoAnnualPayLvlTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waMoLvlTrends.png", replace
# Out:
# . /* Output combined WA-MO Trends */
# . /* Display*/
# . graph combine waMoEmploymentLvlTrends waMoAnnualPayLvlTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waMoLvlTrends.png", replace
# file Output/Graphs/waMoLvlTrends.png written in PNG format
#
# .

# %%
# %%stata
# /* Output combined WA-CA Trends */
# /* Display*/
# graph combine waCaEmploymentLvlTrends waCaAnnualPayLvlTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waCaLvlTrends.png", replace
# Out:
# . /* Output combined WA-CA Trends */
# . /* Display*/
# . graph combine waCaEmploymentLvlTrends waCaAnnualPayLvlTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waCaLvlTrends.png", replace
# file Output/Graphs/waCaLvlTrends.png written in PNG format
#
# .

# %% [markdown]
# ### Job Growth

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg lnEmployment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo, robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Job Growth Trends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     name(waMoEmploymentLnTrends)
# Out:
# . reg lnEmployment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo, robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(21, 16)         =     405.69
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9951
#                                                 Root MSE          =     .09099
#
# ...

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg lnEmployment ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa, robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Job Growth Trends: WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     name(waCaEmploymentLnTrends)
# Out:
# . reg lnEmployment ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa, robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(20, 16)         =          .
#                                                 Prob > F          =          .
#                                                 R-squared         =     0.9074
#                                                 Root MSE          =     .05144
#
# ...

# %% [markdown]
# ### Wage growth

# %% [markdown]
# ### WA-MO Comparison

# %%
# %%stata
# reg lnAnnualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waMo, robust
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annaul Pay Growth Trends: WA-MO) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     name(waMoAnnualPayLnTrends)
# Out:
# . reg lnAnnualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waMo, robust
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
# Linear regression                               Number of obs     =         38
#                                                 F(20, 16)         =          .
#                                                 Prob > F          =          .
#                                                 R-squared         =     0.9939
#                                                 Root MSE          =     .02076
#
# ...

# %% [markdown]
# ### WA-CA Comparison

# %%
# %%stata
# reg lnAnnualPay ///
#     $leads t_0 $lags i.year i.wa ///
#     $covariates if $waCa
#
# coefplot , keep($leads t_0 $lags ) ///
#     vertical title(Annual Pay Growth Trends WA-CA) ///
#     yline(0) ///
#     addplot(line @b @at,lpattern(dash)) ///
#     rename($plotNames) ///
#     graphregion(fcolor(white)) ///
#     name(waCaAnnualPayLnTrends)
# Out:
# . reg lnAnnualPay ///
# >     $leads t_0 $lags i.year i.wa ///
# >     $covariates if $waCa
# note: 2010.year omitted because of collinearity.
# note: 2011.year omitted because of collinearity.
# note: 2012.year omitted because of collinearity.
# note: 2013.year omitted because of collinearity.
# note: 2014.year omitted because of collinearity.
# note: 2015.year omitted because of collinearity.
# note: 2016.year omitted because of collinearity.
# note: 2017.year omitted because of collinearity.
# note: 2019.year omitted because of collinearity.
#
#       Source |       SS           df       MS      Number of obs   =        38
# -------------+----------------------------------   F(21, 16)       =    212.07
#        Model |  1.02922149        21  .049010547   Prob > F        =    0.0000
#     Residual |  .003697718        16  .000231107   R-squared       =    0.9964
# -------------+----------------------------------   Adj R-squared   =    0.9917
# ...

# %% [markdown]
# ### Combine WA/MO Employment and Pay Trends

# %%
# %%stata
# /* Output combined WA-MO Trends */
# /* Display*/
# graph combine waMoEmploymentLnTrends waMoAnnualPayLnTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waMoLnTrends.png", replace
# Out:
# . /* Output combined WA-MO Trends */
# . /* Display*/
# . graph combine waMoEmploymentLnTrends waMoAnnualPayLnTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waMoLnTrends.png", replace
# file Output/Graphs/waMoLnTrends.png written in PNG format
#
# .

# %%
# %%stata
# /* Output combined WA-CA Trends */
# /* Display*/
# graph combine waCaEmploymentLnTrends waCaAnnualPayLnTrends, ///
#     rows(2) cols(1)
#
# /* Save to $output folder */
# graph export "$graphs/waCaLnTrends.png", replace
# Out:
# . /* Output combined WA-CA Trends */
# . /* Display*/
# . graph combine waCaEmploymentLnTrends waCaAnnualPayLnTrends, ///
# >     rows(2) cols(1)
#
# .
# . /* Save to $output folder */
# . graph export "$graphs/waCaLnTrends.png", replace
# file Output/Graphs/waCaLnTrends.png written in PNG format
#
# .

# %% [markdown]
# ## DID Model - Missouri

# %%
# %%stata
# // Job Growth DID Model
# reg employment ///
#     i.wa postIncentive treated ///
#     if $waMo, robust
#
# eststo employmentRegBasicMo
#
# reg employment ///
#     i.wa postIncentive treated ///
#     $covariates if $waMo, robust
#
# eststo employmentRegCovariatesMo
#
#
# // Wages DID Model
# reg annualPay ///
#     i.wa postIncentive treated ///
#     if $waMo, robust
#
# eststo wagesRegBasicMo
#
# reg annualPay ///
#     i.wa postIncentive treated ///
#     $covariates if $waMo, robust
#
# eststo wagesRegCovariatesMo
# Out:
# . // Job Growth DID Model
# . reg employment ///
# >     i.wa postIncentive treated ///
# >     if $waMo, robust
#
# Linear regression                               Number of obs     =         38
#                                                 F(3, 34)          =     701.94
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.9659
#                                                 Root MSE          =       6699
#
# ------------------------------------------------------------------------------
#              |               Robust
#   employment | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         1.wa |   64611.31   3065.235    21.08   0.000        58382    70840.61
# postIncent~e |    1898.91   467.5237     4.06   0.000     948.7878    2849.033
# ...

# %%
# %%stata
# /* Results */
# esttab employmentRegBasicMo employmentRegCovariatesMo ///
#     wagesRegBasicMo wagesRegCovariatesMo, ///
#     noconstant se ar2 obslast scalars(F) ///
#     keep(treated)  ///
#     order(treated) ///
#     coeflabels(treated "DID ATT") ///
#     indicate(Covariates = $covariates) ///
#     title("Washington-Missouri DID Estimates")
# Out:
# . /* Results */
# . esttab employmentRegBasicMo employmentRegCovariatesMo ///
# >     wagesRegBasicMo wagesRegCovariatesMo, ///
# >     noconstant se ar2 obslast scalars(F) ///
# >     keep(treated)  ///
# >     order(treated) ///
# >     coeflabels(treated "DID ATT") ///
# >     indicate(Covariates = $covariates)
#
# ----------------------------------------------------------------------------
#                       (1)             (2)             (3)             (4)
#                employment      employment       annualPay       annualPay
# ----------------------------------------------------------------------------
# DID ATT            7882.5*        -1570.7           902.6        -21964.0***
#                  (3557.8)        (5436.9)        (5252.0)        (4192.0)
#
# Covariates             No             Yes              No             Yes
# ----------------------------------------------------------------------------
# ...

# %%
# %%stata
# /* Results */
# esttab employmentRegBasicMo employmentRegCovariatesMo ///
#     wagesRegBasicMo wagesRegCovariatesMo ///
#     using $tables/waMoDid.tex, replace ///
#     noconstant se ar2 obslast scalars(F) ///
#     keep(treated)  ///
#     order(treated) ///
#     coeflabels(treated "DID ATT") ///
#     indicate(Covariates = $covariates)
# Out:
# . /* Results */
# . esttab employmentRegBasicMo employmentRegCovariatesMo ///
# >     wagesRegBasicMo wagesRegCovariatesMo ///
# >     using $tables/waMoDid.tex, replace ///
# >     noconstant se ar2 obslast scalars(F) ///
# >     keep(treated)  ///
# >     order(treated) ///
# >     coeflabels(treated "DID ATT") ///
# >     indicate(Covariates = $covariates)
# (output written to Output/Tables/waMoDid.tex)
#
# .

# %% [markdown]
# ## DID Model - Washington California

# %%
# %%stata
# // Job Growth DID Model
# reg employment ///
#     i.wa postIncentive treated ///
#     if $waCa, robust
#
# eststo employmentRegBasicCa
#
# reg employment ///
#     i.wa postIncentive treated ///
#     $covariates if $waCa, robust
#
# eststo employmentRegCovariatesCa
#
#
# // Wages DID Model
# reg annualPay ///
#     i.wa postIncentive treated ///
#     if $waCa, robust
#
# eststo wagesRegBasicCa
#
# reg annualPay ///
#     i.wa postIncentive treated ///
#     $covariates if $waCa, robust
#
# eststo wagesRegCovariatesCa
# Out:
# . // Job Growth DID Model
# . reg employment ///
# >     i.wa postIncentive treated ///
# >     if $waCa, robust
#
# Linear regression                               Number of obs     =         38
#                                                 F(3, 34)          =      20.43
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.3870
#                                                 Root MSE          =     7180.8
#
# ------------------------------------------------------------------------------
#              |               Robust
#   employment | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         1.wa |   5989.231   3276.586     1.83   0.076    -669.5929    12648.05
# postIncent~e |       1462    1524.97     0.96   0.344    -1637.113    4561.113
# ...

# %%
# %%stata
# /* Results */
# esttab employmentRegBasicCa employmentRegCovariatesCa ///
#     wagesRegBasicCa wagesRegCovariatesCa, ///
#     noconstant se ar2 obslast scalars(F) ///
#     keep(treated)  ///
#     order(treated) ///
#     coeflabels(treated "DID ATT") ///
#     indicate(Covariates = $covariates) ///
#     title("Washington-California DID Estimates")
# Out:
# . /* Results */
# . esttab employmentRegBasicCa employmentRegCovariatesCa ///
# >     wagesRegBasicCa wagesRegCovariatesCa, ///
# >     noconstant se ar2 obslast scalars(F) ///
# >     keep(treated)  ///
# >     order(treated) ///
# >     coeflabels(treated "DID ATT") ///
# >     indicate(Covariates = $covariates) ///
# >     title("Washington-California DID Estimates")
#
# Washington-California DID Estimates
# ----------------------------------------------------------------------------
#                       (1)             (2)             (3)             (4)
#                employment      employment       annualPay       annualPay
# ----------------------------------------------------------------------------
# DID ATT            8319.4*         6801.4          6186.8         29287.7***
#                  (3842.5)        (4784.4)        (5254.7)        (4831.1)
#
# Covariates             No             Yes              No             Yes
# ...

# %%
# %%stata
# /* Results */
# esttab employmentRegBasicCa employmentRegCovariatesCa ///
#     wagesRegBasicCa wagesRegCovariatesCa ///
#     using $tables/waCaDid.tex, replace ///
#     noconstant se ar2 obslast scalars(F) ///
#     keep(treated)  ///
#     order(treated) ///
#     coeflabels(treated "DID ATT") ///
#     indicate(Covariates = $covariates)
# Out:
# . /* Results */
# . esttab employmentRegBasicCa employmentRegCovariatesCa ///
# >     wagesRegBasicCa wagesRegCovariatesCa ///
# >     using $tables/waCaDid.tex, replace ///
# >     noconstant se ar2 obslast scalars(F) ///
# >     keep(treated)  ///
# >     order(treated) ///
# >     coeflabels(treated "DID ATT") ///
# >     indicate(Covariates = $covariates)
# (output written to Output/Tables/waCaDid.tex)
#
# .

# %%
# %%capture
# %%stata
clear
log close

# %%
# %%stata
# graph drop *
